# %% [markdown]
# # Topic modelling - с помощью Gensim

# %%
# !pip install pandas
# !pip install gensim
# !pip install nltk
# !pip install pymorphy2
# !pip install tqdm

import pandas as pd

import numpy as np
# Out:
# Requirement already satisfied: pandas in /home/mitya/37env/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /home/mitya/37env/lib/python3.7/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2017.3 in /home/mitya/37env/lib/python3.7/site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/mitya/37env/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/mitya/37env/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: gensim in /home/mitya/37env/lib/python3.7/site-packages (4.1.2)
# Requirement already satisfied: smart-open>=1.8.1 in /home/mitya/37env/lib/python3.7/site-packages (from gensim) (5.2.1)
# Requirement already satisfied: numpy>=1.17.0 in /home/mitya/37env/lib/python3.7/site-packages (from gensim) (1.21.5)
# Requirement already satisfied: scipy>=0.18.1 in /home/mitya/37env/lib/python3.7/site-packages (from gensim) (1.7.3)
# Requirement already satisfied: nltk in /home/mitya/37env/lib/python3.7/site-packages (3.7)
# Requirement already satisfied: joblib in /home/mitya/37env/lib/python3.7/site-packages (from nltk) (1.1.0)
# Requirement already satisfied: click in /home/mitya/37env/lib/python3.7/site-packages (from nltk) (8.1.2)
# Requirement already satisfied: tqdm in /home/mitya/37env/lib/python3.7/site-packages (from nltk) (4.63.1)
# Requirement already satisfied: regex>=2021.8.3 in /home/mitya/37env/lib/python3.7/site-packages (from nltk) (2022.3.15)
# Requirement already satisfied: importlib-metadata in /home/mitya/37env/lib/python3.7/site-packages (from click->nltk) (4.11.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/mitya/37env/lib/python3.7/site-packages (from importlib-metadata->click->nltk) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /home/mitya/37env/lib/python3.7/site-packages (from importlib-metadata->click->nltk) (3.7.0)
# Requirement already satisfied: pymorphy2 in /home/mitya/37env/lib/python3.7/site-packages (0.9.1)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in /home/mitya/37env/lib/python3.7/site-packages (from pymorphy2) (2.4.417127.4579844)
# Requirement already satisfied: dawg-python>=0.7.1 in /home/mitya/37env/lib/python3.7/site-packages (from pymorphy2) (0.7.2)
# Requirement already satisfied: docopt>=0.6 in /home/mitya/37env/lib/python3.7/site-packages (from pymorphy2) (0.6.2)
# Requirement already satisfied: tqdm in /home/mitya/37env/lib/python3.7/site-packages (4.63.1)

# %%
import nltk

nltk.download('stopwords')

from nltk.corpus import stopwords

from gensim.utils import simple_preprocess

from nltk.corpus import stopwords

import pymorphy2

from tqdm import tqdm
# Out:
# [nltk_data] Downloading package stopwords to /home/mitya/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Вначале - датасет. Это собранные короткие предложения с википедии, которые можно найти по ссылке:
# https://wortschatz.uni-leipzig.de/en/download/Russian
#
# Далее - предобработка. Возьмем наши предложения, разобъем на слова, удалим стоп-слова, лемматизируем остальные - приведем их к нормальной форме с помощью pymorphy2.

# %%
sentences = open('rus_wikipedia_2021_1M-sentences.txt', 'r')
sentences_list = []
stop_words = stopwords.words('russian')
stop_words.extend(stopwords.words('english'))
morph = pymorphy2.MorphAnalyzer()
for i in tqdm(range(100000)):
    line = simple_preprocess(sentences.readline())
    l = []
    for word in line:
        if word not in stop_words:
            try:
                norm = morph.parse(word)[0].normal_form
                l.append(norm)
            except:
                l.append(word)
    sentences_list.append(l)
# Out:
# 100%|██████████████████████████████████| 100000/100000 [02:51<00:00, 582.03it/s]

# %%
sentences_list[:5]
# Out:
# [['проект',
#   'концепция',
#   'свободный',
#   'экономический',
#   'зона',
#   'одесса',
#   'этап',
#   'интеграция',
#   'украина',
#   'европейский',
#   'союз'],
#  ['декабрь', 'год'],
#  ['дислокация',
#   'войсковой',
#   'часть',
#   'штаб',
#   'управление',
#   'учреждение',
#   'заведение',
#   'рабочий',
#   'крестьянский',
#   'красный',
#   'армия',
#   'состояние',
#   'июль',
#   'год'],
#  ['июль', 'забить', 'первый', 'мяч', 'клуб', 'поразить', 'ворота'],
#  ['год',
#   'уволить',
#   'запас',
#   'возраст',
#   'формулировка',
#   'период',
#   'пребывание',
#   'заключение',
#   'ссылка',
#   'засчитываться',
#   'счёт',
#   'пребывание',
#   'служба',
#   'кадр',
#   'армия']]

# %% [markdown]
# Далее - создадим биграммы. Таким образом, Российская Федерация, Премьер-Лига и т.д. должны в итоге выглядеть как российский_федерация, премьер_лига, ...

# %%
from gensim.models import Phrases


bigram = Phrases(sentences_list, min_count=10, threshold=20)

# %%
list(bigram[sentences_list])[:5]
# Out:
# [['проект',
#   'концепция',
#   'свободный',
#   'экономический',
#   'зона',
#   'одесса',
#   'этап',
#   'интеграция',
#   'украина',
#   'европейский',
#   'союз'],
#  ['декабрь', 'год'],
#  ['дислокация',
#   'войсковой',
#   'часть',
#   'штаб',
#   'управление',
#   'учреждение',
#   'заведение',
#   'рабочий_крестьянский',
#   'красный_армия',
#   'состояние',
#   'июль',
#   'год'],
#  ['июль', 'забить', 'первый', 'мяч', 'клуб', 'поразить', 'ворота'],
#  ['год',
#   'уволить_запас',
#   'возраст',
#   'формулировка',
#   'период',
#   'пребывание',
#   'заключение',
#   'ссылка',
#   'засчитываться',
#   'счёт',
#   'пребывание',
#   'служба',
#   'кадр',
#   'армия']]

# %% [markdown]
# Далее - обучим Word2Vec. Подберем оптимальные параметры, ориентируясь на то, какие слова по идее должны стать синонимами. После этого обучим Word2Vec с оптимальными параметрами.

# %%
from gensim.models import Word2Vec


min_count_selection = [1, 3, 5, 7, 9]
window_selection = [3, 5]
vector_size_selection = [60, 70, 80]
grouped_params = [[min_count, window, vector_size] for min_count in min_count_selection 
                  for window in window_selection 
                  for vector_size in vector_size_selection]
synonyms = [('российский_федерация', 'рф'), ('машина', 'авто'), 
            ('университет', 'колледж'), ('эсминец', 'линкор'),
            ('село', 'деревня'), ('ссср', 'советский_союз')]
for group in grouped_params:
    cnt_syns = 0
    syn_diffs = 0.0
    model = Word2Vec(bigram[sentences_list], min_count=group[0], 
                     epochs=20, window=group[1], vector_size=group[2])
    print('min_count is: ' + str(group[0]) + ' and '
          'window is: ' + str(group[1]) + ' and vector_size is: ' + str(group[2]))
    closest_first = model.wv.most_similar(pair[0])
    closest_last = model.wv.most_similar(pair[1])
    for pair in synonyms:
        if model.wv.most_similar(pair[0])[0][0] == pair[1]:
            if model.wv.most_similar(pair[1])[0][0] == pair[0]:
                print(str(pair[0]) + ' and ' + pair[1] + ' are counted as synomyms')
                sum_diffs_first = model.wv.most_similar(pair[0])[0][1] - model.wv.most_similar(pair[0])[1][1]
                print('sum of differences from closest word to ' + pair[0] + ' is: ' + str(sum_diffs_first))
                sum_diffs_second = model.wv.most_similar(pair[1])[0][1] - model.wv.most_similar(pair[1])[1][1]
                print('sum of differences from closest word to ' + pair[1] + ' is: ' + str(sum_diffs_second))
                cnt_syns += 1
                syn_diffs += sum_diffs_first + sum_diffs_second

                
    print('number of found synonyms is ' + str(cnt_syns) + ' and total step is ' + str(syn_diffs))
    print(syn_diffs)
    print('#============================================================#')
# Out:
# min_count is: 1 and window is: 3 and vector_size is: 60
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.01161336898803711
# sum of differences from closest word to деревня is: 0.04401487112045288
# number of found synonyms is 1 and total step is 0.05562824010848999
# 0.05562824010848999
# #============================================================#
# min_count is: 1 and window is: 3 and vector_size is: 70
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.017843902111053467
# sum of differences from closest word to деревня is: 0.0186956524848938
# number of found synonyms is 1 and total step is 0.036539554595947266
# 0.036539554595947266
# #============================================================#
# min_count is: 1 and window is: 3 and vector_size is: 80
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.02577030658721924
# sum of differences from closest word to деревня is: 0.03171682357788086
# number of found synonyms is 1 and total step is 0.0574871301651001
# 0.0574871301651001
# #============================================================#
# min_count is: 1 and window is: 5 and vector_size is: 60
# университет and колледж are counted as synomyms
# sum of differences from closest word to университет is: 0.06193947792053223
# sum of differences from closest word to колледж is: 0.0025236010551452637
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.022986888885498047
# sum of differences from closest word to деревня is: 0.040624141693115234
# number of found synonyms is 2 and total step is 0.12807410955429077
# 0.12807410955429077
# #============================================================#
# min_count is: 1 and window is: 5 and vector_size is: 70
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.027646422386169434
# sum of differences from closest word to деревня is: 0.011822760105133057
# number of found synonyms is 1 and total step is 0.03946918249130249
# 0.03946918249130249
# #============================================================#
# min_count is: 1 and window is: 5 and vector_size is: 80
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.039667367935180664
# sum of differences from closest word to деревня is: 0.018516182899475098
# number of found synonyms is 1 and total step is 0.05818355083465576
# 0.05818355083465576
# #============================================================#
# min_count is: 3 and window is: 3 and vector_size is: 60
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.05787426233291626
# sum of differences from closest word to деревня is: 0.058315813541412354
# number of found synonyms is 1 and total step is 0.11619007587432861
# 0.11619007587432861
# #============================================================#
# min_count is: 3 and window is: 3 and vector_size is: 70
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.021114826202392578
# sum of differences from closest word to деревня is: 0.01943284273147583
# number of found synonyms is 1 and total step is 0.04054766893386841
# 0.04054766893386841
# #============================================================#
# min_count is: 3 and window is: 3 and vector_size is: 80
# университет and колледж are counted as synomyms
# sum of differences from closest word to университет is: 0.02039724588394165
# sum of differences from closest word to колледж is: 0.013194859027862549
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.03626847267150879
# sum of differences from closest word to деревня is: 0.034469008445739746
# number of found synonyms is 2 and total step is 0.10432958602905273
# 0.10432958602905273
# #============================================================#
# min_count is: 3 and window is: 5 and vector_size is: 60
# университет and колледж are counted as synomyms
# sum of differences from closest word to университет is: 0.06782233715057373
# sum of differences from closest word to колледж is: 0.030406951904296875
# эсминец and линкор are counted as synomyms
# sum of differences from closest word to эсминец is: 0.00936955213546753
# sum of differences from closest word to линкор is: 0.012659549713134766
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.02774733304977417
# sum of differences from closest word to деревня is: 0.04506206512451172
# number of found synonyms is 3 and total step is 0.1930677890777588
# 0.1930677890777588
# #============================================================#
# min_count is: 3 and window is: 5 and vector_size is: 70
# российский_федерация and рф are counted as synomyms
# sum of differences from closest word to российский_федерация is: 0.004922986030578613
# sum of differences from closest word to рф is: 0.015033364295959473
# университет and колледж are counted as synomyms
# sum of differences from closest word to университет is: 0.052947938442230225
# sum of differences from closest word to колледж is: 0.010818243026733398
# эсминец and линкор are counted as synomyms
# sum of differences from closest word to эсминец is: 0.017283856868743896
# sum of differences from closest word to линкор is: 0.01784348487854004
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.015006303787231445
# sum of differences from closest word to деревня is: 0.025931894779205322
# number of found synonyms is 4 and total step is 0.1597880721092224
# 0.1597880721092224
# #============================================================#
# min_count is: 3 and window is: 5 and vector_size is: 80
# российский_федерация and рф are counted as synomyms
# sum of differences from closest word to российский_федерация is: 0.008053123950958252
# sum of differences from closest word to рф is: 0.01914656162261963
# университет and колледж are counted as synomyms
# sum of differences from closest word to университет is: 0.046446800231933594
# sum of differences from closest word to колледж is: 0.003798365592956543
# эсминец and линкор are counted as synomyms
# sum of differences from closest word to эсминец is: 0.007930099964141846
# sum of differences from closest word to линкор is: 0.02602088451385498
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.037473440170288086
# sum of differences from closest word to деревня is: 0.04833662509918213
# number of found synonyms is 4 and total step is 0.19720590114593506
# 0.19720590114593506
# #============================================================#
# min_count is: 5 and window is: 3 and vector_size is: 60
# университет and колледж are counted as synomyms
# sum of differences from closest word to университет is: 0.06184154748916626
# sum of differences from closest word to колледж is: 0.053331613540649414
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.055101752281188965
# sum of differences from closest word to деревня is: 0.05633264780044556
# number of found synonyms is 2 and total step is 0.2266075611114502
# 0.2266075611114502
# #============================================================#
# min_count is: 5 and window is: 3 and vector_size is: 70
# университет and колледж are counted as synomyms
# sum of differences from closest word to университет is: 0.045409440994262695
# sum of differences from closest word to колледж is: 0.037478089332580566
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.028469383716583252
# sum of differences from closest word to деревня is: 0.03256028890609741
# number of found synonyms is 2 and total step is 0.14391720294952393
# 0.14391720294952393
# #============================================================#
# min_count is: 5 and window is: 3 and vector_size is: 80
# университет and колледж are counted as synomyms
# sum of differences from closest word to университет is: 0.043319642543792725
# sum of differences from closest word to колледж is: 0.040870606899261475
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.04910123348236084
# sum of differences from closest word to деревня is: 0.03927868604660034
# number of found synonyms is 2 and total step is 0.17257016897201538
# 0.17257016897201538
# #============================================================#
# min_count is: 5 and window is: 5 and vector_size is: 60
# университет and колледж are counted as synomyms
# sum of differences from closest word to университет is: 0.0709492564201355
# sum of differences from closest word to колледж is: 0.03701364994049072
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.029790878295898438
# sum of differences from closest word to деревня is: 0.03038156032562256
# number of found synonyms is 2 and total step is 0.16813534498214722
# 0.16813534498214722
# #============================================================#
# min_count is: 5 and window is: 5 and vector_size is: 70
# российский_федерация and рф are counted as synomyms
# sum of differences from closest word to российский_федерация is: 0.0014309287071228027
# sum of differences from closest word to рф is: 0.031622469425201416
# университет and колледж are counted as synomyms
# sum of differences from closest word to университет is: 0.05161166191101074
# sum of differences from closest word to колледж is: 0.03928738832473755
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.018155992031097412
# sum of differences from closest word to деревня is: 0.01753067970275879
# number of found synonyms is 3 and total step is 0.1596391201019287
# 0.1596391201019287
# #============================================================#
# min_count is: 5 and window is: 5 and vector_size is: 80
# российский_федерация and рф are counted as synomyms
# sum of differences from closest word to российский_федерация is: 0.004858255386352539
# sum of differences from closest word to рф is: 0.013697981834411621
# университет and колледж are counted as synomyms
# sum of differences from closest word to университет is: 0.06804031133651733
# sum of differences from closest word to колледж is: 0.029007315635681152
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.015952885150909424
# sum of differences from closest word to деревня is: 0.026560544967651367
# number of found synonyms is 3 and total step is 0.15811729431152344
# 0.15811729431152344
# #============================================================#
# min_count is: 7 and window is: 3 and vector_size is: 60
# университет and колледж are counted as synomyms
# sum of differences from closest word to университет is: 0.06599617004394531
# sum of differences from closest word to колледж is: 0.06491845846176147
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.047430574893951416
# sum of differences from closest word to деревня is: 0.05986523628234863
# number of found synonyms is 2 and total step is 0.23821043968200684
# 0.23821043968200684
# #============================================================#
# min_count is: 7 and window is: 3 and vector_size is: 70
# университет and колледж are counted as synomyms
# sum of differences from closest word to университет is: 0.04146385192871094
# sum of differences from closest word to колледж is: 0.021442174911499023
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.02720850706100464
# sum of differences from closest word to деревня is: 0.044865429401397705
# number of found synonyms is 2 and total step is 0.1349799633026123
# 0.1349799633026123
# #============================================================#
# min_count is: 7 and window is: 3 and vector_size is: 80
# университет and колледж are counted as synomyms
# sum of differences from closest word to университет is: 0.03663158416748047
# sum of differences from closest word to колледж is: 0.015885591506958008
# эсминец and линкор are counted as synomyms
# sum of differences from closest word to эсминец is: 0.0038377046585083008
# sum of differences from closest word to линкор is: 0.019101619720458984
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.047494590282440186
# sum of differences from closest word to деревня is: 0.05004853010177612
# number of found synonyms is 3 and total step is 0.17299962043762207
# 0.17299962043762207
# #============================================================#
# min_count is: 7 and window is: 5 and vector_size is: 60
# российский_федерация and рф are counted as synomyms
# sum of differences from closest word to российский_федерация is: 0.013413310050964355
# sum of differences from closest word to рф is: 0.01600545644760132
# университет and колледж are counted as synomyms
# sum of differences from closest word to университет is: 0.022301316261291504
# sum of differences from closest word to колледж is: 0.006430327892303467
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.036277949810028076
# sum of differences from closest word to деревня is: 0.03243452310562134
# number of found synonyms is 3 and total step is 0.12686288356781006
# 0.12686288356781006
# #============================================================#
# min_count is: 7 and window is: 5 and vector_size is: 70
# российский_федерация and рф are counted as synomyms
# sum of differences from closest word to российский_федерация is: 0.0008713603019714355
# sum of differences from closest word to рф is: 0.004601836204528809
# университет and колледж are counted as synomyms
# sum of differences from closest word to университет is: 0.03760915994644165
# sum of differences from closest word to колледж is: 0.014461040496826172
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.02701115608215332
# sum of differences from closest word to деревня is: 0.00732654333114624
# number of found synonyms is 3 and total step is 0.09188109636306763
# 0.09188109636306763
# #============================================================#
# min_count is: 7 and window is: 5 and vector_size is: 80
# российский_федерация and рф are counted as synomyms
# sum of differences from closest word to российский_федерация is: 0.02047067880630493
# sum of differences from closest word to рф is: 0.011939764022827148
# университет and колледж are counted as synomyms
# sum of differences from closest word to университет is: 0.031168758869171143
# sum of differences from closest word to колледж is: 0.01741814613342285
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.021902382373809814
# sum of differences from closest word to деревня is: 0.00458604097366333
# number of found synonyms is 3 and total step is 0.10748577117919922
# 0.10748577117919922
# #============================================================#
# min_count is: 9 and window is: 3 and vector_size is: 60
# российский_федерация and рф are counted as synomyms
# sum of differences from closest word to российский_федерация is: 0.00843733549118042
# sum of differences from closest word to рф is: 0.07819026708602905
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.050374507904052734
# sum of differences from closest word to деревня is: 0.03525722026824951
# number of found synonyms is 2 and total step is 0.17225933074951172
# 0.17225933074951172
# #============================================================#
# min_count is: 9 and window is: 3 and vector_size is: 70
# университет and колледж are counted as synomyms
# sum of differences from closest word to университет is: 0.030592024326324463
# sum of differences from closest word to колледж is: 0.017123878002166748
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.10226577520370483
# sum of differences from closest word to деревня is: 0.07130849361419678
# number of found synonyms is 2 and total step is 0.22129017114639282
# 0.22129017114639282
# #============================================================#
# min_count is: 9 and window is: 3 and vector_size is: 80
# российский_федерация and рф are counted as synomyms
# sum of differences from closest word to российский_федерация is: 0.009093999862670898
# sum of differences from closest word to рф is: 0.07543063163757324
# университет and колледж are counted as synomyms
# sum of differences from closest word to университет is: 0.028641462326049805
# sum of differences from closest word to колледж is: 0.0025963187217712402
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.039433181285858154
# sum of differences from closest word to деревня is: 0.044651925563812256
# number of found synonyms is 3 and total step is 0.1998475193977356
# 0.1998475193977356
# #============================================================#
# min_count is: 9 and window is: 5 and vector_size is: 60
# российский_федерация and рф are counted as synomyms
# sum of differences from closest word to российский_федерация is: 0.021044611930847168
# sum of differences from closest word to рф is: 0.04711240530014038
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.010466694831848145
# sum of differences from closest word to деревня is: 0.038625240325927734
# number of found synonyms is 2 and total step is 0.11724895238876343
# 0.11724895238876343
# #============================================================#
# min_count is: 9 and window is: 5 and vector_size is: 70
# российский_федерация and рф are counted as synomyms
# sum of differences from closest word to российский_федерация is: 0.00393223762512207
# sum of differences from closest word to рф is: 0.05048578977584839
# университет and колледж are counted as synomyms
# sum of differences from closest word to университет is: 0.0697488784790039
# sum of differences from closest word to колледж is: 0.025492310523986816
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.02977168560028076
# sum of differences from closest word to деревня is: 0.04338306188583374
# number of found synonyms is 3 and total step is 0.22281396389007568
# 0.22281396389007568
# #============================================================#
# min_count is: 9 and window is: 5 and vector_size is: 80
# российский_федерация and рф are counted as synomyms
# sum of differences from closest word to российский_федерация is: 0.004635035991668701
# sum of differences from closest word to рф is: 0.04796898365020752
# университет and колледж are counted as synomyms
# sum of differences from closest word to университет is: 0.047678470611572266
# sum of differences from closest word to колледж is: 0.01562601327896118
# село and деревня are counted as synomyms
# sum of differences from closest word to село is: 0.026601672172546387
# sum of differences from closest word to деревня is: 0.03850829601287842
# number of found synonyms is 3 and total step is 0.18101847171783447
# 0.18101847171783447
# #============================================================#

# %%
from gensim.models import Word2Vec


model = Word2Vec(bigram[sentences_list], min_count=3, 
                     epochs=20, window=5, vector_size=80)

# %%
model.wv.most_similar('рф')
# Out:
# [('розничный', 0.7888621091842651),
#  ('доллар_сша', 0.7767943739891052),
#  ('коммутация', 0.77588951587677),
#  ('синтетический', 0.775061309337616),
#  ('сотовый', 0.773492157459259),
#  ('платёж', 0.7660769820213318),
#  ('кофе', 0.7572059631347656),
#  ('битум', 0.7567898631095886),
#  ('выплавка', 0.7558321356773376),
#  ('газа', 0.7531812191009521)]

# %%
model.wv.most_similar('российский_федерация')
# Out:
# [('рф', 0.8606249690055847),
#  ('республика_беларусь', 0.8526559472084045),
#  ('усср', 0.8525670170783997),
#  ('президиум', 0.8207685947418213),
#  ('совет_министр', 0.8127041459083557),
#  ('рсфср', 0.8085163235664368),
#  ('почётный_грамота', 0.7993912100791931),
#  ('финансы', 0.779633641242981),
#  ('присуждение', 0.7791944146156311),
#  ('юстиция', 0.7762808203697205)]

# %% [markdown]
# Библиотека Faiss - уступает самому Gensim в качестве и скорости определения косинусного сходства, поэтому используем Gensim.

# %%
faiss_code = '''!pip install faiss-cpu

from faiss import IndexFlatIP

def standard_scale(list_coordinates):
    summ = 0
    for num in list_coordinates:
        summ += num**2
    return list_coordinates/summ**(1/2)


list_preprocessed = list(bigram[sentences_list])
count_dict = {}
for i in range(len(list_preprocessed)):
    for j in range(len(list_preprocessed[i])):
        word = list_preprocessed[i][j]
        count_dict[word] = count_dict.get(word, 0) + 1
index = IndexFlatIP(80)
for word in count_dict.keys():
    index.add(np.array([standard_scale(model.wv[word])]))'''

# %% [markdown]
# Для каждой пары синонимов найдем более популярное слово, и заменим второе из пары на него, во всех текстах.

# %%
replace_dict = {}
for i in tqdm(range(len(list_preprocessed))):
    for j in range(len(list_preprocessed[i])):
        word = list_preprocessed[i][j]
        if replace_dict.get(word, None) != None:
            list_preprocessed[i][j] = replace_dict.get(word)
        else:
            #D, I = index.search(standard_scale(model.wv[[word]]), 2) 
            #counterpart = list(count_dict.keys())[I.squeeze()[1]]
            #D, I = index.search(standard_scale(model.wv[[counterpart]]), 2) 
            #if word == list(count_dict.keys())[I.squeeze()[1]]:
            try:
                counterpart = model.wv.most_similar(word, topn=1)[0][0]
                if word == model.wv.most_similar(counterpart, topn=1)[0][0]:
                    if count_dict[counterpart] >= count_dict[word]:
                        replace_dict[word] = counterpart
                        list_preprocessed[i][j] = counterpart
                    else:
                        replace_dict[counterpart] = word
            except:
                pass
# Out:
# 100%|██████████████████████████████████| 100000/100000 [13:32<00:00, 123.06it/s]

# %%
replace_dict
# Out:
# {'экономика': 'экономический',
#  'заведение': 'учебный_заведение',
#  'июль': 'апрель',
#  'забить': 'гол',
#  'забросить': 'ворота',
#  'уволить_запас': 'демобилизовать',
#  'взрослый': 'возраст',
#  'кадр': 'подготовка',
#  'войско': 'армия',
#  'существенный': 'значительный',
#  'суметь': 'смочь',
#  'www': 'https',
#  'премьера': 'дебют',
#  'кхл': 'премьер_лига',
#  'синий': 'жёлтый',
#  'турне': 'тур',
#  'кубок': 'чемпионат',
#  'играть': 'выступать',
#  'преимущественно': 'основное',
#  'первый_дивизион': 'дубль',
#  'кавказ': 'сибирь',
#  'приблизительно': 'полтора',
#  'три': 'два',
#  'получать': 'получить',
#  'выходить': 'выйти',
#  'четвертьфинал': 'полуфинал',
#  'уефа': 'кубок_англия',
#  'основать': 'создать',
#  'школа_пилот': 'военный_авиационный',
#  'сей_пора': 'настоящий_время',
#  'выпускаться': 'выпускать',
#  'газета': 'журнал',
#  'шум': 'проба',
#  'видимый': 'обычно',
#  'генетический': 'анализ',
#  'внешне': 'следующий_образ',
#  'сформулировать': 'заключаться',
#  'абстрактный': 'смысл',
#  'должный': 'тот',
#  'фирма': 'компания',
#  'февраль': 'июнь',
#  'скончаться': 'умереть',
#  'отбор': 'групповой',
#  'представлять_себя': 'включать',
#  'конституция': 'закон',
#  'рф': 'российский_федерация',
#  'миллиард': 'доллар',
#  'небесный': 'скорее',
#  'пётр': 'николай',
#  'январь': 'май',
#  'стать_обладательница': 'стать_обладатель',
#  'шаблон': 'таблица',
#  'сочинение': 'произведение',
#  'живописец': 'художник',
#  'картинный': 'галерея',
#  'ленинград': 'киев',
#  'просветительный': 'культурно',
#  'итальянский': 'немецкий',
#  'завершиться': 'закончиться',
#  'привести': 'произойти',
#  'появляться': 'появиться',
#  'удостоить_почётный': 'присвоить_почётный',
#  'гроссмейстер': 'мастер_спорт',
#  'пенальти': 'плей_офф',
#  'восток': 'север',
#  'олег': 'игорь',
#  'просидеть': 'отсидеть',
#  'немецкий_войско': 'взятие',
#  'гвардейский': 'полк',
#  'временно': 'вынудить',
#  'среди': 'число',
#  'исследователь': 'учёный',
#  'выпускник': 'преподаватель',
#  'колледж': 'университет',
#  'мемуары': 'воспоминание',
#  'повторить': 'принести',
#  'одобрение': 'признание',
#  'единственный': 'последний',
#  'средневековый': 'древний',
#  'религия': 'религиозный',
#  'армянин': 'племя',
#  'артиллерийский_огонь': 'артиллерия',
#  'начинать': 'начать',
#  'расхождение': 'творить',
#  'pocket': 'неточность',
#  'министр_внутренний': 'министерство_внутренний',
#  'командировать': 'направить',
#  'ассортимент': 'продукция',
#  'подросток': 'ребёнок',
#  'овца': 'корова',
#  'считаться_один': 'считаться',
#  'полок': 'рота',
#  'штурм': 'осада',
#  'принудить': 'овладеть',
#  'воин': 'солдат',
#  'читать': 'писать',
#  'распоряжение': 'приказ',
#  'архиепископ': 'епископ',
#  'лукин': 'звание_почётный',
#  'отличие': 'степень',
#  'xix_век': 'век',
#  'царство': 'империя',
#  'византиец': 'беглец',
#  'впоследствии': 'поздний',
#  'снова': 'вновь',
#  'закончить_карьера': 'завершить_карьера',
#  'трижды': 'дважды',
#  'нога': 'голова',
#  'десятилетие': 'неделя',
#  'покидать': 'покинуть',
#  'хит_парад': 'чарт',
#  'принимать_участие': 'участвовать',
#  'соревнование': 'турнир',
#  'диаметр': 'ширина',
#  'пятьдесят': 'тридцать',
#  'становиться': 'являться',
#  'гибель': 'смерть',
#  'салат': 'мясной',
#  'разведка': 'запас',
#  'обещать': 'попросить',
#  'приз': 'награда',
#  'занять': 'занимать',
#  'синод': 'братство',
#  'публичный_библиотека': 'архив',
#  'один_инициатор': 'инициатор',
#  'замужем': 'выйти_замуж',
#  'большой': 'больший',
#  'манчестер': 'юнайтед',
#  'северокорейский': 'ответный',
#  'флайёрзнуть': 'пост_главное',
#  'препарат': 'механизм',
#  'медицина': 'наука',
#  'конкретный': 'иной',
#  'пять': 'четыре',
#  'шифр': 'обозначение',
#  'компромиссный': 'решение',
#  'папа': 'король',
#  'вернуть': 'сохранить',
#  'мелодрама': 'комедия',
#  'монтировать': 'трагикомедия',
#  'балет': 'опера',
#  'записывать': 'записать',
#  'ветер': 'холодный',
#  'северный_америка': 'япония',
#  'генри': 'чарльз',
#  'уильям': 'барон',
#  'многочисленный': 'множество',
#  'адаптация': 'аниме',
#  'мотив': 'сюжет',
#  'сооружение': 'комплекс',
#  'жилой_дом': 'жилой',
#  'больший_популярность': 'известность',
#  'воссоздать': 'возвратить',
#  'певец': 'певица',
#  'урожд': 'уродить',
#  'муж': 'жена',
#  'издать': 'опубликовать',
#  'художественный_литература': 'очерковый',
#  'машиностроение': 'промышленность',
#  'понятие': 'особенность',
#  'свидетельствовать': 'сохраниться',
#  'поэт': 'писатель',
#  'xii_век': 'xiii_век',
#  'франция': 'германия',
#  'поговорка': 'пословица',
#  'полицейский': 'полиция',
#  'опера_балет': 'мариинский',
#  'петербург': 'санкт_петербург',
#  'графика': 'компьютерный',
#  'протяжение': 'течение',
#  'девочка': 'мальчик',
#  'груз': 'пассажир',
#  'океан': 'побережье',
#  'заняться': 'заниматься',
#  'бросить': 'пойти',
#  'больший_успех': 'успех',
#  'ниже': 'выше',
#  'живопись': 'художественный',
#  'прогрессив': 'разговорный',
#  'отрывок': 'поэма',
#  'земной': 'человеческий',
#  'раса': 'животное',
#  'шашечный': 'шахматный',
#  'востребовать': 'заметный',
#  'живописный': 'монументальный',
#  'описывать': 'отмечать',
#  'восточный': 'западный',
#  'азиатский': 'африканский',
#  'критиковать': 'рассматриваться',
#  'монгольский': 'российский_империя',
#  'мужской': 'женский',
#  'реорганизовать': 'преобразовать',
#  'серебряный': 'золотой',
#  'заместитель_начальник': 'начальник',
#  'укрепление': 'крепость',
#  'комментарий': 'заметка',
#  'разный': 'различный',
#  'junior': 'ultimate',
#  'дк': 'новосибирск',
#  'изобразительный_искусство': 'прикладной_искусство',
#  'телеканал': 'радио',
#  'больший_часть': 'большинство',
#  'недостаточный': 'точность',
#  'бомбардировщик': 'вертолёт',
#  'хоровой': 'камерный',
#  'воспроизведение': 'гибкий',
#  'джейн': 'мэри',
#  'мёртвый': 'случайно',
#  'запрос': 'регистрация',
#  'лад': 'цинциннать',
#  'рождественский': 'немой',
#  'трагически': 'автокатастрофа',
#  'рассказать': 'рассказывать',
#  'оборонный': 'дорожный',
#  'подозревать': 'убийство',
#  'редакция': 'издательство',
#  'роль_фильм': 'оскар',
#  'клюв': 'свойственно',
#  'сати': 'амплуа',
#  'сочинить': 'симфония',
#  'справиться': 'угрожать',
#  'кинокомпания': 'телекомпания',
#  'associated': 'guide',
#  'девять': 'десять',
#  'комиссия': 'комитет',
#  'теория_практика': 'филологический',
#  'всероссийский': 'всесоюзный',
#  'входить': 'войти',
#  'усср': 'рсфср',
#  'приостановить': 'прекратить',
#  'триллер': 'фильм_ужас',
#  'крыса': 'наоборот',
#  'эван': 'бенитёс',
#  'сценарист': 'режиссёр',
#  'кафе': 'ресторан',
#  'гостиница': 'отель',
#  'постановка': 'спектакль',
#  'десяток': 'сто',
#  'мадемуазель': 'бишоп',
#  'актриса': 'актёр',
#  'феррис': 'богарт',
#  'второй_мировой': 'великий_отечественный',
#  'палестина': 'беженец',
#  'военный_действие': 'боевой_действие',
#  'южный': 'северный',
#  'вагнер': 'снять_фильм',
#  'провести_матч': 'сыграть_матч',
#  'подвергаться': 'способствовать',
#  'второй_план': 'сыграть_главный',
#  'прилив': 'нуар',
#  'чей': 'богатый',
#  'электрофорез': 'паразитический',
#  'нимфа': 'лишать',
#  'догонять': 'вытащить',
#  'buffalo': 'ужин',
#  'измена': 'публично',
#  'отрасль': 'сфера',
#  'нацистский': 'фашистский',
#  'берлин': 'париж',
#  'периодический_издание': 'альманах',
#  'член_редколлегия': 'главный_редактор',
#  'середина': 'конец',
#  'синтезатор': 'нежный',
#  'дебютировать_кино': 'сыграть_роль',
#  'великобритания': 'сша',
#  'наблюдаться': 'влиять',
#  'взнос': 'денежный',
#  'шеннон': 'майкл',
#  'философско': 'библейский',
#  'подружиться': 'беспринципный',
#  'сержант': 'лейтенант',
#  'бизнесмен': 'адвокат',
#  'зло': 'помнить',
#  'соседка': 'мама',
#  'соединить': 'расположить',
#  'молдаванин': 'ненависть',
#  'съёмка_фильм': 'съёмка',
#  'поездка': 'путешествие',
#  'кинокарьера': 'актёрский_карьера',
#  'оживлённый': 'запоминаться',
#  'полковник': 'генерал',
#  'любовник': 'героиня',
#  'фольклор': 'поэзия',
#  'фэнтези': 'вестерн',
#  'научно_фантастический': 'приключенческий',
#  'опухоль': 'мозг',
#  'прошение': 'просьба',
#  'подходящий': 'безопасный',
#  'приключенческий': 'научно_фантастический',
#  'перекрёсток': 'пересечение',
#  'оказывать': 'оказать',
#  'рекламировать': 'начинающий',
#  'ценитель': 'гимн',
#  'аранжировка': 'мелодия',
#  'нью_йорк': 'лондон',
#  'жениться_актриса': 'тереза',
#  'фред': 'эмиль',
#  'фостер': 'бэйль',
#  'келли': 'джина',
#  'немецко_фашистский': 'захватчик',
#  'герцог': 'граф',
#  'беременный': 'пропасть',
#  'ловля': 'рыбный',
#  'джо': 'питер',
#  'сниматься_кино': 'сниматься',
#  'эмоция': 'воспринимать',
#  'номинал': 'монета',
#  'апач': 'неизвестный_причина',
#  'обучаться': 'учиться',
#  'несчастный': 'выпить',
#  'кредит': 'банковский',
#  'борт': 'экипаж',
#  'десятый': 'шестой',
#  'обозреватель': 'пресса',
#  'спешить': 'пришелец',
#  'маска': 'волос',
#  'телесериал': 'сериал',
#  'погоня': 'бандит',
#  'зрительный': 'зал',
#  'субсидия': 'монополия',
#  'тираж': 'экземпляр',
#  'хранить': 'собранный',
#  'playhouse': 'wm',
#  'слышать': 'страх',
#  'заместитель_главное': 'редактор_журнал',
#  'районный': 'областной',
#  'снятой': 'снять',
#  'канадский': 'австралийский',
#  'добавлять': 'добавить',
#  'население': 'житель',
#  'героизм': 'мужество',
#  'тон': 'похожий',
#  'подключение': 'оптический',
#  'человечество': 'насилие',
#  'дожить': 'отложить',
#  'операторский': 'режиссёрский',
#  'внешнеторговый': 'сберегательный',
#  'вина': 'слух',
#  'предупреждать': 'прекращать',
#  'двадцатка': 'десятка',
#  'амон': 'черчилль',
#  'рассказываться': 'описываться',
#  'габриэла': 'атлантида',
#  'поддельный': 'резидент',
#  'телебашня': 'веяние',
#  'столетний': 'юбилей',
#  'заложник': 'боевик',
#  'танец': 'музыка',
#  'блюзовый': 'поп',
#  'любовница': 'подруга',
#  'юмористический': 'стихотворный',
#  'кэри': 'знаковый',
#  'датский': 'шведский',
#  'финансирование': 'финансовый',
#  'расовый': 'радикальный',
#  'правый': 'левый',
#  'колонист': 'колония',
#  'трое': 'двое',
#  'доминго': 'санто',
#  'вица': 'губернатор',
#  'укусить': 'крепко',
#  'сексуальный': 'поведение',
#  'судьба': 'любовь',
#  'изображать': 'изобразить',
#  'храм': 'церковь',
#  'спаситель': 'христос',
#  'стихотворение': 'стих',
#  'проводиться': 'проходить',
#  'ссылаться': 'отрицать',
#  'младший': 'старший',
#  'des': 'der',
#  'супермен': 'расправиться',
#  'здорово': 'бэкон',
#  'благоустройство': 'застройка',
#  'культурный_наследие': 'культурный',
#  'последующий': 'предыдущий',
#  'ричард': 'джордж',
#  'минь_сериал': 'телефильм',
#  'сосредоточиться': 'возобновить',
#  'помещение': 'здание',
#  'пятизвёздочный': 'душевая',
#  'сражение': 'битва',
#  'латвийский': 'белорусский',
#  'деревня': 'село',
#  'претворить': 'повседневный',
#  'дирекция': 'бюро',
#  'неудачный': 'удачный',
#  'оборачиваться': 'преданность',
#  'вторичный': 'исходный',
#  'оливер': 'дэн',
#  'союз_композитор': 'союз_писатель',
#  'garden': 'продюсерский',
#  'предатель': 'гнев',
#  'змея': 'волк',
#  'весна': 'осень',
#  'католический': 'православный',
#  'тбилисский': 'физкультура',
#  'алексей': 'андрей',
#  'мерфь': 'пейдж',
#  'княгиня': 'екатерина',
#  'фельетон': 'анекдот',
#  'внук': 'дочь',
#  'рокк': 'морган',
#  'публично': 'измена',
#  'глобус': 'пальма',
#  'патрульный': 'спасательный',
#  'шоссе': 'долина',
#  'присоединяться': 'вступать',
#  'эпизодический_роль': 'небольшой_роль',
#  'председатель_правление': 'член_правление',
#  'базза': 'алисий',
#  'республиканец': 'оппозиция',
#  'либерал': 'демократ',
#  'открытость': 'гордиться',
#  'карате': 'призываться',
#  'school': 'high',
#  'iii': 'ii',
#  'поступить_продажа': 'анонсировать',
#  'киноакадемия': 'соискание',
#  'срежиссировать': 'реж',
#  'kiss': 'сиквел',
#  'научно_методический': 'социально',
#  'отзыв_музыкальный': 'положительный_отзыв',
#  'парный': 'четвёрка',
#  'экспонат': 'экспозиция',
#  'шерсть': 'молоко',
#  'конструкторский': 'проектный',
#  'спин': 'офф',
#  'дитрих': 'красавица',
#  'обл': 'ул',
#  'оргкомитет': 'жюри',
#  'скрипка': 'фортепиано',
#  'буддизм': 'тибетский',
#  'сестра': 'мать',
#  'отзыв': 'критик',
#  'естественный_наука': 'физико_математический',
#  'направляться': 'доставить',
#  'висячий': 'пролёт',
#  'подвергнуть': 'вызвать',
#  'вмс': 'ввс',
#  'аргентина': 'бразилия',
#  'элитный': 'резервный',
#  'озеро': 'река',
#  'батэ': 'бразилец',
#  'светский': 'духовный',
#  'аун': 'хосе',
#  'млрд': 'млн',
#  'стоимость': 'цена',
#  'штрафной': 'колено',
#  'рипнуть': 'взрывать',
#  'манускрипт': 'рукопись',
#  'нахождение': 'приближаться',
#  'пост': 'должность',
#  'шаттл': 'час_минута',
#  'увеличиваться': 'уменьшаться',
#  'снижение': 'увеличение',
#  'реализовать': 'предоставлять',
#  'присудить': 'удостоить',
#  'штык': 'ружьё',
#  'mls': 'суперлига',
#  'отрывочный': 'скудный',
#  'составить': 'составлять',
#  'awards': 'award',
#  'молли': 'саманта',
#  'заслужить_тренер': 'народный_артист',
#  'неоднозначный': 'весьма',
#  'репутация': 'шанс',
#  'размеренный': 'монолог',
#  'привычка': 'вроде',
#  'алан': 'адам',
#  'бо_льшуя': 'бо_льшать',
#  'популяризация': 'творческий',
#  'самоуправление': 'автономия',
#  'обратить_внимание': 'допустить',
#  'архитектурный': 'архитектура',
#  'генеральный_директор': 'вица_президент',
#  'копировать': 'примечательный',
#  'pedro': 'культивировать',
#  'общаться': 'помогать',
#  'шекспировский': 'шекспир',
#  'лауреат': 'стать_лауреат',
#  'сцепление': 'гелий',
#  'полихромный': 'матисс',
#  'руководить': 'возглавлять',
#  'укрыться': 'вторгнуться',
#  'старший_тренер': 'главный_тренер',
#  'эллисон': 'ferrari',
#  'эми': 'брэндон',
#  'школьный': 'детский',
#  'лиза': 'бен',
#  'миля': 'км',
#  'филипп': 'королева',
#  'фрагмент': 'лист',
#  'дэнить': 'эдёр',
#  'рекс': 'свидание',
#  'co': 'company',
#  'напрямую': 'подчинённый',
#  'гумилёв': 'шиллер',
#  'янг': 'крис',
#  'сервис': 'онлайн',
#  'смотритель': 'попечитель',
#  'уголовный': 'судебный',
#  'звание_генерал': 'майор',
#  'повсюду': 'плохо',
#  'джошуа': 'сильвестрить',
#  'китон': 'брюстер',
#  'кладовая': 'ванна',
#  'ао': 'оао',
#  'сообщение': 'информация',
#  'sleeping': 'century',
#  'переговоры': 'кампания',
#  'место_чарт': 'строчка',
#  'авианосец': 'крейсер',
#  'минеральный': 'газ',
#  'указ_президиум': 'верховный_совет',
#  'институт_специальность': 'техникум',
#  'делегат': 'съезд',
#  'разгромный': 'полуфинальный',
#  'нхл': 'драфт',
#  'договор': 'соглашение',
#  'утром': 'утро',
#  'раненый': 'ранить',
#  'получить_приглашение': 'цска',
#  'vii': 'iv',
#  'ревизия': 'перепись',
#  'один_наиболее': 'один_самый',
#  'казна': 'имущество',
#  'отравление': 'ранение',
#  'излечение': 'истощение',
#  'кавалерийский': 'пехотный',
#  'домохозяин': 'иметься_хозяйство',
#  'рейс': 'аэропорт',
#  'михаилович': 'николаевич',
#  'вне': 'установление',
#  'пушечный': 'фрегат',
#  'немецкий_оккупация': 'визит',
#  'экологически': 'резина',
#  'покрышка': 'змеиный',
#  'молодёжный_команда': 'право_аренда',
#  'несколько_месяц': 'некоторый_время',
#  'разместиться': 'располагаться',
#  'academy': 'кино_телевидение',
#  'wi': 'fi',
#  'осуществляться': 'обеспечивать',
#  'батальон': 'дивизия',
#  'восхищение': 'ухудшиться',
#  'records': 'лейбл',
#  'произвести_генерал': 'поручик',
#  'принять_вооружение': 'ил',
#  'выступ': 'балка',
#  'фигурный': 'садовый',
#  'коммуникация': 'ресурс',
#  'узбекистан': 'казахстан',
#  'футбольный_команда': 'футбольный_клуб',
#  'синтетический': 'полимер',
#  'бас': 'гитара',
#  'калибр': 'мм',
#  'работать_преподаватель': 'отличие_окончить',
#  'доктор_исторический': 'доктор_наука',
#  'декан': 'доцент',
#  'рядовой': 'военнослужащий',
#  'глубина': 'поверхность',
#  'писание': 'аристотель',
#  'африка': 'азия',
#  'обосноваться': 'перебраться',
#  'второй_дивизион': 'второй_лига',
#  'греческий': 'арабский',
#  'постамент': 'бюст',
#  'трансляция': 'эфир',
#  'дания': 'бельгия',
#  'норвегия': 'австрия',
#  'нидерланды': 'швеция',
#  'транслировать': 'транслироваться',
#  'осип': 'евгения',
#  'серебряков': 'острог',
#  'входить_состав': 'войти_состав',
#  'kane': 'published',
#  'published': 'kane',
#  'матвеев': 'захаров',
#  'cut': 'def',
#  'грузовой': 'пассажирский',
#  'изобильненский': 'рудоуправление',
#  'локомотивный': 'коммунальный',
#  'роща': 'дубовый',
#  'баум': 'новокузнецк',
#  'арматурный': 'авторемонтный',
#  'shot': 'вдовец',
#  'пулемёт': 'пушка',
#  'зима': 'зимой',
#  'государственный_служба': 'пенсия',
#  'славный': 'обычай',
#  'постсоветский': 'стремление',
#  'двукратный': 'серебряный_призёр',
#  'закрыться': 'закрытый',
#  'комплект': 'набор',
#  'бродяга': 'близко',
#  'неподалёку': 'недалеко',
#  'xvii': 'xviii',
#  'увезти': 'угнать',
#  'визуальный': 'анимация',
#  'индский': 'ост',
#  'комсомольск': 'амур',
#  'аэродром': 'порт',
#  'башмачок': 'пингвин',
#  'страничный': 'русский_перевод',
#  'тёрнер': 'бал',
#  'пуд': 'тонна',
#  'осудить': 'приговорить',
#  'смертный_казнь': 'расстрел',
#  'ncaa': 'побить',
#  'peter': 'von',
#  'назначить_командир': 'командовать',
#  'страхование': 'добровольный',
#  'иран': 'турция',
#  'обучение': 'курс',
#  'иваново': 'калининград',
#  'паша': 'шах',
#  'помешать': 'остановить',
#  'соответствующий': 'распределение',
#  'превышать': 'достигать',
#  'лейба_гвардия': 'полковой',
#  'милан': 'прага',
#  'чернов': 'амнон',
#  'программный_обеспечение': 'программный',
#  'однородный': 'широкий_распространение',
#  'бегство': 'заставить',
#  'нередко': 'часто',
#  'взлёт': 'посадка',
#  'глубоко': 'грех',
#  'обыденный': 'эмоциональный',
#  'урон': 'наносить',
#  'запад': 'юг',
#  'ab': 'чайный',
#  'ablativus': 'падеж',
#  'сравнительный': 'анатомия',
#  'корень': 'происхождение',
#  'рождаться': 'родить',
#  'слог': 'глагол',
#  'перемещение': 'удаление',
#  'агентство': 'банк',
#  'латвия': 'литва',
#  'edition': 'cd',
#  'гравюра': 'рисунок',
#  'abu': 'dhabi',
#  'dhabi': 'abu',
#  'prix': 'grand',
#  'чемпионат_европа': 'чемпионат_мир',
#  'иначе': 'точно',
#  'выполняться': 'применяться',
#  'темп': 'быстрый',
#  'реликвия': 'безумец',
#  'разрез': 'посуда',
#  'занять_третий': 'занять_второе',
#  'арьергард': 'отдать_приказ',
#  'португальский': 'испанский',
#  'авиация': 'флот',
#  'открыть_огонь': 'отбить',
#  'аккредитация': 'аккредитовать',
#  'отклик': 'рецензия',
#  'епископальный': 'методистский',
#  'гарвард': 'психолог',
#  'half': 'spider',
#  'life': 'new',
#  'учитывать': 'применять',
#  'purvis': 'обжаловать',
#  'рукоятка': 'рама',
#  'югославия': 'венгрия',
#  'закупить': 'заказать',
#  'выделить_её': 'учредить_епархия',
#  'рассмотрение': 'проверка',
#  'альбом_переиздать': 'переиздать',
#  'подчинить': 'упразднить',
#  'поддержать': 'обвинить',
#  'переизбрание': 'вынесение',
#  'поприще': 'практика',
#  'studies': 'books',
#  'балалайка': 'фольклорный',
#  'дверной': 'удлинённый',
#  'седан': 'кузов',
#  'диапазон': 'частота',
#  'замедлять': 'сечь',
#  'brand': 'studio',
#  'adventures': 'sky',
#  'narcine': 'эндемик',
#  'обучиться': 'причислять',
#  'революционер': 'ирландский',
#  'югослав': 'шторм',
#  'эли': 'гофман',
#  'os': 'mac',
#  'военный_воздушный': 'военный_морской',
#  'сократиться': 'увеличиться',
#  'тулон': 'vor',
#  'general': 'ag',
#  'light': 'girl',
#  'трансмиссия': 'оснащаться',
#  'скорректировать': 'разгореться',
#  'пристав': 'приамурский',
#  'shadows': 'blood',
#  'заводский_серийный': 'регистрационный_номер',
#  'hong': 'kong',
#  'nippon': 'airways',
#  'низкоплан': 'купальня',
#  'одноразовый': 'ai',
#  'интерфейс': 'процессор',
#  'ярко': 'оттенок',
#  'вбок': 'телескопический',
#  'отремонтировать': 'разобрать',
#  'theatre': 'цирковой',
#  'придавать': 'отражать',
#  'пригородный': 'трамвайный',
#  'риверсайда': 'урология',
#  'полноформатный_альбом': 'студийный_альбом',
#  'пианист': 'джазовый',
#  'мифология': 'философ',
#  'румынский': 'сербский',
#  'romeo': 'alfa',
#  'холдинг': 'концерн',
#  'автогонки': 'дженять',
#  'chains': 'alice',
#  'следить': 'незаконный',
#  'сбросить': 'вниз',
#  'ssl': 'концепт',
#  'обязаться': 'мирный_договор',
#  'четвёртый_место': 'третий_место',
#  'кос': 'густой',
#  'газотурбинный': 'дизельный',
#  'rock': 'love',
#  'years': 'never',
#  'мотоцикл': 'автомобиль',
#  'экспорт': 'поставка',
#  'пятнадцать': 'течение_два',
#  'train': 'herald',
#  'ближний_восток': 'восточный_европа',
#  'программно': 'совместимость',
#  'плавный': 'микросхема',
#  'алюминиевый': 'медный',
#  'racing': 'team',
#  'основывать': 'начать_работать',
#  'заповедный': 'охранять',
#  'electronics': 'холдинговый',
#  'химия': 'физика',
#  'john': 'american',
#  'исполнительный_директор': 'председатель_совет',
#  'выставлять': 'выставить',
#  'ежеквартальный': 'ежемесячный',
#  'менять': 'сохранять',
#  'радиатор': 'бампер',
#  'фара': 'решётка',
#  'фолкнуть': 'дуэт',
#  'тюркский': 'персидский',
#  'параметр': 'измерение',
#  'приятный': 'мрачный',
#  'мачеха': 'править',
#  'подлинный': 'любовный',
#  'фортепианный': 'вокальный',
#  'увольнение': 'подать_отставка',
#  'налоговый': 'таможенный',
#  'целое_положительный': 'основное_положительный',
#  'проработка': 'нововведение',
#  'красота': 'красивый',
#  'machine': 'death',
#  'princess': 'nbc',
#  'greater': 'manitoba',
#  'annual': 'knock',
#  'book': 'new_york',
#  'простота': 'качественный',
#  'белли': 'девичество',
#  'пожениться': 'развестись',
#  'браницкий': 'побудить',
#  'структурный': 'входящий',
#  'ген': 'белок',
#  'симпозиум': 'форум',
#  'черчение': 'рисование',
#  'движок': 'intel',
#  'отчётность': 'платёж',
#  'специфика': 'тестирование',
#  'строительство_новый': 'реконструкция',
#  'иисус': 'божий',
#  'накопитель': 'ггц',
#  'мач': 'fl',
#  'бухгалтерия': 'обобщённый',
#  'хоккейный': 'любительский',
#  'вещественный': 'множественный',
#  'усилитель': 'сборка',
#  'диагональ': 'совпадать',
#  'tonight': 'everything',
#  'состояние_здоровье': 'выйти_отставка',
#  'конституционный': 'принятие',
#  'модерн': 'барокко',
#  'прочий': 'большой_количество',
#  'blu': 'ray',
#  'marmalade': 'sdk',
#  'трактовка': 'выражение',
#  'ролевый': 'аркадный',
#  'сигнализация': 'контроллер',
#  'media': 'video',
#  'католицизм': 'положить_конец',
#  'типичный': 'расположение',
#  'интенсивный': 'подъём',
#  'привить': 'увлечься',
#  'astra': 'ranger',
#  'нейрон': 'оболочка',
#  'matthew': 'matter',
#  'prius': 'commodore',
#  'manufacturing': 'amway',
#  'amway': 'manufacturing',
#  'дискуссия': 'обсуждение',
#  'college': 'university',
#  'лирический': 'баллада',
#  'существенно': 'характеристика',
#  'quattro': 'audi',
#  'genesis': 'audio',
#  'сенсор': 'модифицировать',
#  'парень': 'девушка',
#  'устанавливать': 'производиться',
#  'бозить': 'раскритиковать',
#  'artist': 'year',
#  'еловый': 'гусеница',
#  'королевский_академия': 'академия_художество',
#  'прогрессировать': 'расстроить',
#  'индексирование': 'dos',
#  'провести_реконструкция': 'двухэтажный',
#  'осуществить': 'приступить',
#  'маятник': 'дозаправка',
#  'country': 'let',
#  'fl': 'мач',
#  'бойз': 'реал',
#  'вклад_развитие': 'большой_вклад',
#  'молл': 'вронский',
#  'дозволение': 'таки',
#  'лотос': 'балийский',
#  'батарейка': 'sr',
#  'сфабриковать': 'причастность',
#  'доказательство': 'никакой',
#  'обязательство': 'ответственность',
#  'брюс': 'билл',
#  'bangkok': 'sekiyu',
#  'видеоклип': 'клип',
#  'сосредоточить': 'связывать',
#  'federal': 'ипотечный',
#  'courier': 'daily',
#  'убитый_раненый': 'человек_убитый',
#  'данный_момент': 'сегодняшний_день',
#  'древовидный': 'маршрутизация',
#  'удобный': 'надёжный',
#  'пенсильвания': 'филадельфия',
#  'хён': 'габриэль',
#  'заболеть': 'тяжело',
#  'слабоумие': 'миокард',
#  'ларс': 'расторгнуть',
#  'ощущение': 'насколько',
#  'свойственный': 'отличать',
#  'нуль': 'одинаковый',
#  'уменьшить': 'увеличить',
#  'фюзеляж': 'подвеска',
#  'сыр': 'масло',
#  'мох': 'болотистый',
#  'древность': 'буддийский',
#  'albums': 'chart',
#  'неслыханный': 'дуб',
#  'stranger': 'beautiful',
#  'национальный_отбор': 'евровидение',
#  'истребление': 'геноцид',
#  'индивид': 'вовлечение',
#  'служение': 'гонение',
#  'нож': 'пистолет',
#  'чебоксары': 'мн',
#  'оттуда': 'обратно',
#  'исследуться': 'ассимиляция',
#  'добиваться': 'проявить',
#  'выкупить': 'купить',
#  'ссуда': 'задолженность',
#  'viking': 'зажигательный',
#  'прима': 'клоун',
#  'nano': 'zala',
#  'заинтересовать': 'посчитать',
#  'ограничиваться': 'летучий',
#  'blues': 'pink',
#  'попадаться': 'чудовище',
#  'определитель': 'гриб',
#  'blanco': 'kg',
#  'island': 'gmbh',
#  'kg': 'blanco',
#  'кг': 'вес',
#  'говядина': 'заполняться',
#  'минь_альбом': 'ep',
#  'азот': 'белка',
#  'удлинённый': 'дверной',
#  'понять': 'понимать',
#  'оаэ': 'чартерный',
#  'кровать': 'карман',
#  'goverlan': 'reach',
#  'стамбул': 'мадрид',
#  'прослушивать': 'комфортный',
#  'общность': 'идентичность',
#  'дальность': 'стрельба',
#  'издать_книга': 'опубликовать_книга',
#  'writer': 'boston',
#  'назаров': 'гонец',
#  'панорамный': 'тепловоз',
#  'загородный': 'старое',
#  'гибралтар': 'нанести_удар',
#  'самостоятельно': 'постоянно',
#  'gp': 'камаз',
#  'диета': 'визуализация',
#  'глиняный': 'гранитный',
#  'христианство': 'ислам',
#  'подвоз': 'коммандос',
#  'прилететь': 'ма',
#  'statesman': 'record',
#  'странно': 'айк',
#  'рабство': 'индеец',
#  'заострить': 'подвешиваться',
#  'xvii_xviii': 'xviii_xix',
#  'сборочный': 'ответвление',
#  'oxford': 'university_press',
#  'серебро': 'золото',
#  'уменьшать': 'жидкость',
#  'electronic': 'arts',
#  'инновационный': 'внедрение',
#  'животноводство': 'окружающий_среда',
#  'завершить_спортивный': 'прервать',
#  'раундовый': 'оппонент',
#  'плагиат': 'запрещение',
#  'затрата': 'нагрузка',
#  'изменчивость': 'эволюционный',
#  'активация': 'рецептор',
#  'клеточный': 'синтез',
#  'проверить': 'пересмотреть',
#  'bros': 'warner',
#  'самарский_губерния': 'губерния',
#  'конический': 'образный',
#  'базирование': 'полигон',
#  'заниматься_футбол': 'спортклуб',
#  'renault': 'ram',
#  'кутузов': 'краснознамённый',
#  'союзмультфильм': 'редакция_газета',
#  'редактировать': 'издавать',
#  'наставник': 'знакомство',
#  'сертификация': 'сертификат',
#  'гильдия': 'купец',
#  'ехать': 'отправляться',
#  'римско_католический': 'русский_православный',
#  'нефть': 'месторождение',
#  'египет': 'королевство',
#  'екатеринослав': 'псков',
#  'нижнелужицкий': 'иврит',
#  'министерство_юстиция': 'уполномоченный',
#  'эмиграция': 'эмигрант',
#  'префектура': 'апостольский_викариат',
#  'антиохия': 'апостольский',
#  'полеводческий_звено': 'звеньевой',
#  'купол': 'башня',
#  'наклон': 'длина_метр',
#  'занимать_пост': 'занимать_должность',
#  'духовный_семинария': 'семинария',
#  'доктор_технический': 'кандидат_технический',
#  'гравирование': 'вроцлавский',
#  'младший_научный': 'старший_научный',
#  'спартак': 'динамо',
#  'мичиганский': 'токийский',
#  'приход': 'община',
#  'ассамблея': 'парламент',
#  'лектор': 'научный_сотрудник',
#  'механизация': 'автоматизация',
#  'пенсионер': 'персональный',
#  'чехословакия': 'швейцария',
#  'развивать': 'готовить',
#  'марбургский': 'оксфордский',
#  'volkswagen': 'toyota',
#  'тверской': 'полтавский',
#  'диктатура': 'трибунал',
#  'неустойчивый': 'реагировать',
#  'антикризисный': 'оказание',
#  'досуг': 'проживание',
#  'morning': 'em',
#  'мобилизовать': 'проходить_служба',
#  'одномандатный': 'государственный_дума',
#  'eos': 'mark',
#  'калифорнийский_университет': 'беркли',
#  'акушер': 'милуока',
#  'воронежский': 'харьковский',
#  'начать_строительство': 'выстроить',
#  'спонсорский': 'эксклюзивный',
#  'браузер': 'веб',
#  'рубинштейн': 'корнеев',
#  'солист': 'дирижёр',
#  'гастролировать': 'гастроль',
#  'экспонироваться': 'выставляться',
#  'первый_этаж': 'второй_этаж',
#  'пост_президент': 'премьер_министр',
#  'катастрофа': 'авария',
#  'линкор': 'эсминец',
#  'стать_называться': 'получить_название',
#  'гидравлический': 'насос',
#  'поместье': 'имение',
#  'патруль': 'член_экипаж',
#  'свести': 'воссоединиться',
#  'плавник': 'брюшной_плавник',
#  'копирование': 'пк',
#  ...}

# %%
list_preprocessed
# Out:
# [['проект',
#   'концепция',
#   'свободный',
#   'экономический',
#   'зона',
#   'одесса',
#   'этап',
#   'интеграция',
#   'украина',
#   'европейский',
#   'союз'],
#  ['декабрь', 'год'],
#  ['дислокация',
#   'войсковой',
#   'часть',
#   'штаб',
#   'управление',
#   'учреждение',
#   'учебный_заведение',
#   'рабочий_крестьянский',
#   'красный_армия',
#   'состояние',
#   'апрель',
#   'год'],
#  ['апрель', 'гол', 'первый', 'мяч', 'клуб', 'поразить', 'ворота'],
#  ['год',
#   'демобилизовать',
#   'возраст',
#   'формулировка',
#   'период',
#   'пребывание',
#   'заключение',
#   'ссылка',
#   'засчитываться',
#   'счёт',
#   'пребывание',
#   'служба',
#   'подготовка',
#   'армия'],
#  ['значительный',
#   'вклад',
#   'образование',
#   'воспитание',
#   'подрастать',
#   'поколение',
#   'вручить',
#   'значок'],
#  ['балл',
#   'ошибка',
#   'компьютер',
#   'смочь',
#   'обеспечить',
#   'отрыв',
#   'соперник',
#   'выиграть',
#   'высокий_лига',
#   'https',
#   'web'],
#  ['затем', 'счёт', 'дом', 'одержать', 'верх'],
#  ['многие', 'болельщик', 'потребовать', 'отставка'],
#  ['состояться', 'дебют', 'премьер_лига'],
#  ['который', 'показать', 'жёлтый', 'карточка'],
#  ['рамка', 'го', 'тур', 'национальный', 'чемпионат'],
#  ['выступать', 'рубин', 'основное', 'дубль'],
#  ['декабрь',
#   'защитник',
#   'денис',
#   'бухряк',
#   'подписать',
#   'новый',
#   'контракт',
#   'сибирь',
#   'срок',
#   'полтора',
#   'год'],
#  ['погибнуть', 'игрок', 'ливорно'],
#  ['сумма', 'два', 'матч'],
#  ['шумский', 'получить', 'главное', 'судья', 'матч', 'жёлтый', 'карточка'],
#  ['гость', 'дом'],
#  ['выйти', 'самый', 'первый', 'минута', 'матч', 'провести', 'поле', 'минута'],
#  ['выйти_замена', 'минута'],
#  ['полуфинал', 'чемпионат', 'обладатель_кубок', 'кубок_англия'],
#  ['заменить', 'минута'],
#  ['результат', 'аннулировать', 'соперник', 'сняться', 'розыгрыш'],
#  ['дебютировать', 'высокий_лига', 'чемпионат', 'украина'],
#  ['сумма', 'два', 'матч'],
#  ['вводить', 'глава', 'администрация', 'белый', 'дом'],
#  ['март',
#   'открыть',
#   'счёт',
#   'свой',
#   'голам',
#   'эйрдрить',
#   'оформить',
#   'дубль',
#   'матч_против'],
#  ['база',
#   'школа',
#   'создать',
#   'вольский',
#   'военный_авиационный',
#   'технический',
#   'училище'],
#  ['ghost', 'настоящий_время', 'выпускать', 'журнал'],
#  ['сс',
#   'год',
#   'создать',
#   'лёгкий',
#   'стрелковый_дивизия',
#   'ленинградский',
#   'армия',
#   'народный',
#   'ополчение',
#   'численность',
#   'человек'],
#  ['весовой',
#   'часть',
#   'каждый',
#   'проба',
#   'обычно',
#   'брать',
#   'химический',
#   'анализ',
#   'изучение',
#   'концентрация',
#   'азотосодержать',
#   'ион',
#   'остальной',
#   'часть',
#   'идти',
#   'анализ'],
#  ['главный',
#   'вопрос',
#   'россия',
#   'следующий_образ',
#   'заключаться',
#   'свой',
#   'вариант',
#   'ответ',
#   'вопрос',
#   'смысл',
#   'жизнь',
#   'бог',
#   'предопределить',
#   'мир',
#   'безграничный',
#   'развитие'],
#  ['главный',
#   'человек',
#   'российский',
#   'искусство',
#   'кто',
#   'тот',
#   'узнавать',
#   'лицо'],
#  ['крупный', 'ит', 'компания', 'россия', 'место'],
#  ['июнь', 'умереть', 'день'],
#  ['выйти', 'групповой', 'этап', 'достаться'],
#  ['начало', 'работа', 'ракета', 'включать', 'копия', 'aim'],
#  ['внесение',
#   'изменение',
#   'федеральный',
#   'закон',
#   'образование',
#   'российский_федерация'],
#  ['доллар'],
#  ['fм',
#   'иметь',
#   'региональный',
#   'статус',
#   'поскольку',
#   'лицензия',
#   'эфирный',
#   'вещание',
#   'белово',
#   'ленинск',
#   'кузнецкий'],
#  ['год',
#   'также',
#   'указать',
#   'скорее',
#   'тело',
#   'который',
#   'называть',
#   'планета',
#   'слънец'],
#  ['трактат',
#   'носить_название',
#   'идея',
#   'граматикия',
#   'мусикийский',
#   'составленый',
#   'прежде',
#   'николай',
#   'дилецкий',
#   'вилна',
#   'послежде',
#   'превести',
#   'славенский',
#   'диалект',
#   'царьствовать',
#   'град',
#   'москва'],
#  ['май', 'год'],
#  ['гость', 'дом', 'стать_обладатель', 'второй', 'международный', 'трофей'],
#  ['выйти_замена', 'минута', 'матч'],
#  ['матч', 'амик', 'одержать_победа', 'панин', 'провести', 'весь', 'матч'],
#  ['декабрь', 'год', 'выйти', 'второй', 'песня'],
#  ['лацио', 'позволить', 'выйти', 'позиция', 'таблица'],
#  ['остаться', 'пример'],
#  ['апрель', 'год'],
#  ['эпизод', 'шестнадцатый', 'сезон', 'признаться', 'лесбиянка'],
#  ['крупный', 'победа', 'игра'],
#  ['год',
#   'независимость',
#   'произведение',
#   'киевский',
#   'художник',
#   'галерея',
#   'лавр',
#   'киев'],
#  ['год', 'независимость', 'республика_казахстан'],
#  ['май',
#   'год',
#   'состояться',
#   'культурно',
#   'поход',
#   'немецкий',
#   'студенчество',
#   'против',
#   'антинемецкий',
#   'дух',
#   'закончиться',
#   'первый',
#   'публичный',
#   'сожжение',
#   'книга'],
#  ['ноябрь', 'произойти', 'рецидив', 'травма'],
#  ['вывести', 'команда', 'финал', 'затем', 'забить_гол', 'донецкий'],
#  ['появиться', 'замена_минута'],
#  ['серия',
#   'сезон',
#   'демонстрироваться',
#   'скелет',
#   'velociraptor',
#   'mongoliensis',
#   'который',
#   'работать',
#   'профессор',
#   'ходжинс'],
#  ['такой_образ', 'вывести', 'команда', 'финал'],
#  ['июнь', 'год'],
#  ['помочь', 'могилевчанин', 'выйти', 'полуфинал', 'чемпионат', 'белоруссия'],
#  ['московский', 'абт', 'центр', 'костеровый', 'ногинск', 'база', 'тбр'],
#  ['нг',
#   'октябрь',
#   'год',
#   'присвоить_почётный',
#   'спортивный',
#   'звание_заслужить',
#   'мастер_спорт',
#   'россия'],
#  ['плей_офф',
#   'футболист',
#   'север',
#   'смочь',
#   'гол',
#   'игорь',
#   'послематчевый',
#   'плей_офф',
#   'южанин',
#   'впервые',
#   'выиграть_кубок',
#   'страна'],
#  ['однако', 'последовать', 'вылет', 'кипрский'],
#  ['история', 'клуб', 'подряд', 'высокий_дивизион'],
#  ['создать', 'условие', 'обогащение', 'процветание', 'орден', 'тамплиер'],
#  ['история', 'клуб', 'подряд', 'высокий_дивизион'],
#  ['год', 'создать', 'одесский', 'кадетский_корпус'],
#  ['октябрь', 'год'],
#  ['август', 'год'],
#  ['плетикос', 'весь', 'матч', 'отсидеть', 'скамейка', 'запасный'],
#  ['бобаля', 'отыграть', 'игра', 'минута'],
#  ['гость', 'дом'],
#  ['второй', 'тайм', 'выйти_замена'],
#  ['декабрь', 'год'],
#  ['декабрь',
#   'взятие',
#   'подхожий',
#   'полк',
#   'повести',
#   'наступление',
#   'сталиногорск'],
#  ['время', 'домашний', 'победа'],
#  ['март', 'год'],
#  ['поле', 'выйти'],
#  ['ноябрь',
#   'год',
#   'вынудить',
#   'окончательно',
#   'признать',
#   'победить',
#   'свой',
#   'противник',
#   'смотреть'],
#  ['ноябрь',
#   'число',
#   'учёный',
#   'преподаватель',
#   'немецкий',
#   'университет',
#   'вуз',
#   'подписать'],
#  ['приводить',
#   'фамилия',
#   'эрики',
#   'фамилия',
#   'дать',
#   'воспоминание',
#   'хель',
#   'сузи'],
#  ['сентябрь',
#   'бенхамин',
#   'забить_гол',
#   'который',
#   'принести',
#   'победа',
#   'команда'],
#  ['июнь', 'состояться', 'товарищеский', 'матч', 'мфк', 'кристалл'],
#  ['матч'],
#  ['эпизод_сериал',
#   'эпизод_сериал',
#   'чародей',
#   'благодаря_что',
#   'получить',
#   'признание',
#   'мир',
#   'кинематограф'],
#  ['возможно',
#   'последний',
#   'полный',
#   'обзор',
#   'героический',
#   'эпос',
#   'древний',
#   'германец',
#   'создать',
#   'сказание',
#   'прорицание',
#   'заклинание',
#   'изречение',
#   'культовый',
#   'религиозный',
#   'обряд',
#   'германский',
#   'племя'],
#  ['декабрь'],
#  ['принять_предложение'],
#  ['миллион', 'просмотр'],
#  ['выпуск',
#   'радиоискатель',
#   'зенитный',
#   'артиллерия',
#   'апрель',
#   'год',
#   'вменяться',
#   'начать',
#   'серийный_производство',
#   'луна',
#   'август',
#   'год'],
#  ['анафематизм',
#   'кирилл',
#   'творить',
#   'христология',
#   'кирилл',
#   'халкидон',
#   'объяснять',
#   'неточность',
#   'кирилл',
#   'сила',
#   'терминология',
#   'время'],
#  ['апрель', 'год', 'стать', 'член_совет', 'министерство_внутренний', 'дело'],
#  ['апрель',
#   'ленкорань',
#   'баксовет',
#   'направить',
#   'отряд',
#   'численность',
#   'человек',
#   'образовать',
#   'рабочий'],
#  ['декабрь', 'год', 'песня'],
#  ['информационный',
#   'продукция',
#   'ребёнок',
#   'достигнуть',
#   'возраст',
#   'двенадцать',
#   'год'],
#  ['это',
#   'поражение',
#   'стать',
#   'третий',
#   'домашний',
#   'подряд',
#   'случиться',
#   'впервые',
#   'год',
#   'урал',
#   'красный',
#   'белые',
#   'проиграть',
#   'брага',
#   'вылет',
#   'лига',
#   'европа'],
#  ['июнь', 'год'],
#  ['октябрь', 'костромской', 'район', 'корова', 'костромской', 'порода'],
#  ['март',
#   'ежедневный',
#   'доклад',
#   'высокий',
#   'командование',
#   'вермахт',
#   'упоминание',
#   'он',
#   'считаться',
#   'исключительный',
#   'честь'],
#  ['открыть', 'счёт', 'забить_гол', 'минута'],
#  ['очко', 'передача', 'победный', 'игра', 'против', 'лидер', 'чемпионат'],
#  ['сумма', 'два', 'матч'],
#  ['сентябрь', 'год'],
#  ['сентябрь', 'год', 'матч', 'закончиться', 'поражение', 'гэлаксить', 'счёт'],
#  ['май', 'год'],
#  ['рота',
#   'осада',
#   'овладеть',
#   'крупный',
#   'опорный',
#   'пункт',
#   'оборона',
#   'противник',
#   'пешхница',
#   'кельцский',
#   'воеводство',
#   'уничтожить',
#   'танк',
#   'автомашина',
#   'орудие',
#   'солдат',
#   'противник'],
#  ['август', 'год', 'монумент', 'отнести', 'памятник', 'значение'],
#  ['голос',
#   'против',
#   'писать',
#   'горбачёв',
#   'такой',
#   'результат',
#   'избрать_президент'],
#  ['октябрь',
#   'год',
#   'директива',
#   'министр_оборона',
#   'республика_казахстан',
#   'июнь',
#   'год'],
#  ['приказ',
#   'мв',
#   'ссср',
#   'март',
#   'год',
#   'выделить',
#   'самостоятельный',
#   'предприятие',
#   'государственный',
#   'союзный',
#   'завод',
#   'подчинение',
#   'му',
#   'главный',
#   'управление',
#   'мв',
#   'ссср'],
#  ['август', 'год', 'матч_против'],
#  ['матч', 'фк'],
#  ['го', 'гидроотряд', 'управление', 'гвф', 'база', 'хабаровск'],
#  ['голый', 'ворота'],
#  ['декабрь', 'год', 'набрать_очко', 'стать', 'личный_рекорд'],
#  ['апрель', 'год'],
#  ['апрель', 'год', 'соединить_штат'],
#  ['июнь', 'год', 'бородин'],
#  ['март',
#   'год',
#   'прибыть',
#   'киев',
#   'март',
#   'святой',
#   'андреевский',
#   'собор',
#   'избрать',
#   'киевский',
#   'епископский',
#   'кафедра',
#   'май',
#   'год',
#   'возвести',
#   'сан',
#   'епископ',
#   'киевский',
#   'чигиринский'],
#  ['май', 'год'],
#  ['место', 'партийный', 'список'],
#  ['персональный_выставка', 'пространство'],
#  ['сентябрь', 'год'],
#  ['футболист', 'дебютировать', 'состав', 'команда', 'чемпионат'],
#  ['учреждение',
#   'звание_почётный',
#   'гражданин',
#   'город',
#   'киев',
#   'поощрительный',
#   'знак',
#   'степень',
#   'киевский',
#   'городской_голова'],
#  ['новый', 'русский', 'слово'],
#  ['умереть',
#   'донателло',
#   'выдающийся',
#   'немецкий',
#   'скульптор',
#   'представитель',
#   'флорентийский',
#   'школа',
#   'ранний',
#   'возрождение'],
#  ['который',
#   'пользоваться',
#   'огромный',
#   'популярность',
#   'ещё',
#   'несколько',
#   'век',
#   'повлиять',
#   'создание',
#   'многий',
#   'произведение_искусство'],
#  ['август', 'год'],
#  ['август', 'год'],
#  ['апрель', 'год'],
#  ['декабрь', 'роман', 'третий', 'трилогия', 'империя', 'зверь'],
#  ['беглец',
#   'поздний',
#   'вновь',
#   'арестовать',
#   'попытка',
#   'вернуться_домой',
#   'китайско',
#   'непальский',
#   'граница'],
#  ['март', 'год'],
#  ['матч', 'мяч', 'завершить_карьера'],
#  ['май', 'год'],
#  ['минута', 'причём', 'дважды', 'переправить', 'мяч', 'сетка', 'голова'],
#  ['неделя', 'покинуть', 'позиция', 'чарт'],
#  ['участвовать', 'турнир'],
#  ['июнь', 'год', 'следующий_день', 'го', 'день_рождение'],
#  ['её', 'личный', 'список', 'премия'],
#  ['название', 'означать', 'ширина', 'молотильный', 'барабан'],
#  ['чемпионат', 'украина', 'среди_любитель'],
#  ['год',
#   'приписывать',
#   'рафаэль',
#   'санти',
#   'либо',
#   'ученик',
#   'тридцать',
#   'год',
#   'являться',
#   'своеобразный',
#   'визитный_карточка',
#   'город'],
#  ['год', 'день', 'смерть', 'великий', 'русский', 'полководец'],
#  ['запечатлеть', 'мелкий', 'деталь', 'мясной', 'продукт'],
#  ['который',
#   'портрет',
#   'исполнить',
#   'форма',
#   'медаль',
#   'сопровождаться',
#   'краткий',
#   'биография'],
#  ['который', 'настоящий_время', 'стоить', 'тележка'],
#  ['август',
#   'год',
#   'вылететь',
#   'запас',
#   'капитан',
#   'сидоренков',
#   'младший_лейтенант',
#   'ведерников'],
#  ['агент',
#   'гивена',
#   'попросить',
#   'руководство',
#   'ньюкасл',
#   'обговорить',
#   'представитель'],
#  ['декабрь',
#   'мин',
#   'взять',
#   'награда',
#   'трек',
#   'fiancé',
#   'музыкальный',
#   'шоу',
#   'show'],
#  ['июнь',
#   'распространение',
#   'тысяча',
#   'копия',
#   'первый',
#   'неделя',
#   'продажа',
#   'занимать',
#   'также',
#   'первый',
#   'позиция'],
#  ['май', 'год'],
#  ['ноябрь',
#   'год',
#   'высокий',
#   'указ',
#   'дать',
#   'братство',
#   'взять',
#   'стража',
#   'дело',
#   'архив',
#   'священный_синод',
#   'видно',
#   'проступок',
#   'арестовать'],
#  ['ноябрь', 'год', 'реабилитировать'],
#  ['октябрь', 'год', 'матч_против'],
#  ['июнь', 'победа'],
#  ['июнь', 'год', 'инициатор', 'выпуск', 'журнал'],
#  ['май', 'год'],
#  ['год', 'др'],
#  ['первый',
#   'наблюдение',
#   'клетка',
#   'использование',
#   'ранний',
#   'микроскоп',
#   'hooke',
#   'robert'],
#  ['спасти', 'корделий', 'смерть', 'выйти_замуж', 'эдгар'],
#  ['написать', 'родиться', 'дувановый', 'выехать', 'больший', 'орда'],
#  ['апрель',
#   'год',
#   'закончиться',
#   'победа',
#   'юнайтед',
#   'счёт',
#   'ответный',
#   'матч'],
#  ['апрель', 'год'],
#  ['июнь',
#   'год',
#   'спортивный',
#   'директор',
#   'черышев',
#   'утвердить',
#   'пост_главное',
#   'тренер'],
#  ['март', 'год', 'уволить', 'болезнь', 'служба'],
#  ['март',
#   'франк',
#   'каменецкий',
#   'механизм',
#   'торможение',
#   'наука',
#   'сборник',
#   'иной',
#   'дать'],
#  ['июнь', 'следующий', 'год'],
#  ['май', 'армида', 'май', 'год'],
#  ['выдержать',
#   'четыре',
#   'переиздание',
#   'считать',
#   'перевод',
#   'использоваться',
#   'обозначение',
#   'декарт',
#   'знак',
#   'равенство',
#   'рекорд'],
#  [],
#  ['являться',
#   'главный',
#   'законодательный',
#   'орган',
#   'стать',
#   'собираться',
#   'решение',
#   'король'],
#  ['год', 'постройка', 'корабль', 'название', 'год', 'постройка'],
#  ['оба', 'учреждение', 'сохранить', 'оригинальный', 'название'],
#  ['давать', 'вполне', 'современный', 'комедия'],
#  ['год',
#   'фраза',
#   'использовать',
#   'описание',
#   'механизм',
#   'влияние',
#   'индивидуальный',
#   'интерес',
#   'максимизация',
#   'общественный',
#   'богатство'],
#  ['который',
#   'студент',
#   'писать',
#   'обсуждать',
#   'свой',
#   'литературный',
#   'произведение',
#   'затем'],
#  ['год', 'законодательно', 'определить', 'порядок', 'дворянский', 'собрание'],
#  ['год',
#   'который',
#   'законодательно',
#   'определить',
#   'порядок',
#   'дворянский',
#   'собрание'],
#  ['включать', 'первый', 'образец', 'трагикомедия', 'опера'],
#  ['танк', 'бригада', 'сдерживать', 'бой', 'голанский', 'высота', 'октябрь'],
#  ['август', 'год', 'против', 'команда'],
#  ['апрель', 'год', 'тур', 'премьер_лига', 'чемпионат_россия'],
#  ['апрель', 'год', 'команда', 'сыграть', 'вничью'],
#  ['декабрь', 'год'],
#  ['место', 'дубль', 'сезон'],
#  ['выйти', 'вид', 'ежемесячник', 'объём', 'страница', 'каждый'],
#  ['апрель', 'место'],
#  ['апрель', 'год', 'записать', 'песня'],
#  ['март', 'год'],
#  ['ноябрь', 'год'],
#  ['октябрь', 'год'],
#  ['октябрь', 'год'],
#  ['сентябрь', 'год', 'рамка', 'эредивизя'],
#  ['июнь', 'выйти_замена', 'минута', 'матч_против'],
#  ['июнь', 'год'],
#  ['май', 'год'],
#  ['соответственно', 'хафпенни', 'занести', 'попытка', 'второй', 'матч'],
#  ['необычайно', 'холодный', 'погода', 'западный_европа', 'япония'],
#  ['также',
#   'персонаж',
#   'выступать',
#   'число',
#   'имя',
#   'чарльз',
#   'франкенштейн',
#   'чарльз',
#   'франкенштейн',
#   'доктор',
#   'франкенштейн',
#   'барон',
#   'франкенштейн',
#   'множество',
#   'книжный',
#   'драматический',
#   'аниме',
#   'сюжет'],
#  ['корпус', 'комплекс', 'жилой', 'будёновский', 'посёлок'],
#  ['создать',
#   'преподаватель',
#   'московский_университет',
#   'изучение',
#   'литература',
#   'философия'],
#  ['будущее',
#   'шелагский',
#   'мыс',
#   'построить',
#   'город',
#   'надежина',
#   'собственный',
#   'университет'],
#  ['принести', 'известность', 'мир', 'московский', 'учёный'],
#  ['год', 'возвратить', 'год'],
#  ['композитор',
#   'жениться',
#   'любить',
#   'давно',
#   'скромный',
#   'французский',
#   'певица',
#   'марь',
#   'мартин',
#   'мария',
#   'женевьев',
#   'берлиоз',
#   'уродить',
#   'мартин',
#   'второй',
#   'жена',
#   'композитор'],
#  ['год',
#   'самостоятельный',
#   'персонаж',
#   'присутствовать',
#   'чудо',
#   'юдо',
#   'рыба',
#   'кит'],
#  ['объединить',
#   'один',
#   'название',
#   'арап',
#   'николай',
#   'великий',
#   'поскольку',
#   'пушкин',
#   'дать',
#   'название',
#   'свой',
#   'исторический',
#   'исследование'],
#  ['год',
#   'кроме',
#   'вместе',
#   'соколовский',
#   'опубликовать',
#   'несколько',
#   'очерковый',
#   'иностранный',
#   'горный',
#   'промышленность'],
#  ['год', 'сотрудничать'],
#  ['который', 'воспевать', 'народный', 'движение', 'xviii_век'],
#  ['показать', 'процесс', 'возникновение', 'особенность'],
#  ['сохраниться',
#   'произведение',
#   'латинский',
#   'церковный',
#   'писатель',
#   'xiii_век',
#   'том'],
#  ['современный',
#   'издание',
#   'пролетарий',
#   'пауперизм',
#   'англия',
#   'германия',
#   'милютин'],
#  ['одетый', 'старенький', 'изорвать', 'сюртук', 'цвет', 'аделаида'],
#  ['год', 'фраза', 'являться', 'пословица', 'парижский', 'полиция', 'чиновник'],
#  ['поздний',
#   'переделать',
#   'трёхактный',
#   'поставить',
#   'год',
#   'сцена',
#   'мариинский',
#   'театр',
#   'санкт_петербург',
#   'москва'],
#  ['работа',
#   'этот',
#   'положить_начало',
#   'изучение',
#   'петербургский',
#   'диптерофауна'],
#  ['skywagon',
#   'шестиместный',
#   'лёгкий',
#   'самолёт',
#   'крыло',
#   'оснастить',
#   'двигатель',
#   'continental',
#   'io',
#   'мощность'],
#  ['театральный',
#   'аниме',
#   'экранизация',
#   'роман',
#   'гиспереть',
#   'хаафса',
#   'ганнибал',
#   'также',
#   'компьютерный',
#   'игра'],
#  ['год', 'это', 'место', 'обозначить', 'больший', 'каишкапканский'],
#  ['переизбрать',
#   'депутат',
#   'конгресс',
#   'депутат',
#   'состав',
#   'который',
#   'оставаться',
#   'течение',
#   'год',
#   'свой',
#   'смерть'],
#  ['третий', 'издание', 'репринт'],
#  ['художник',
#   'попытаться',
#   'возвратить',
#   'психологический',
#   'портрет',
#   'детски',
#   'серьёзный',
#   'мальчик',
#   'который',
#   'довестись',
#   'присматривать',
#   'маленький',
#   'ребёнок'],
#  ['пассажир',
#   'член',
#   'команда',
#   'одноимённый',
#   'корабль',
#   'выжить',
#   'кораблекрушение',
#   'оказаться',
#   'плот',
#   'открытый',
#   'побережье',
#   'вынудить',
#   'заниматься',
#   'людоедство',
#   'умереть',
#   'голод'],
#  ['ге', 'пойти', 'гораздо', 'далёкий'],
#  ['приёмная',
#   'концессионер',
#   'другой',
#   'пользоваться',
#   'успех',
#   'значительно',
#   'уступать',
#   'достоинство',
#   'неравный',
#   'брак',
#   'некоторый',
#   'картина',
#   'выше',
#   'среднее',
#   'уровень',
#   'жанровый',
#   'художественный',
#   'тот',
#   'год'],
#  ['пиратский',
#   'судно',
#   'атаковаться',
#   'топиться',
#   'морской',
#   'мина',
#   'заложить',
#   'капитан',
#   'немо'],
#  ['первый', 'выезд', 'тропинка', 'высокий', 'трава'],
#  ['также',
#   'несколько',
#   'портрет',
#   'член',
#   'семья',
#   'фурнез',
#   'ландшафтный',
#   'полотно',
#   'окрестность'],
#  ['исполнить', 'юмор', 'написать', 'живой', 'разговорный', 'язык'],
#  ['будущность', 'наш', 'образовательный_учреждение', 'первый', 'часть'],
#  ['также', 'такой', 'полотно', 'сад'],
#  ['кн', 'напечатать', 'воспоминание', 'аксаков'],
#  ['сыграть',
#   'важный_роль',
#   'развитие',
#   'национальный',
#   'проза',
#   'частность',
#   'исторический',
#   'роман'],
#  ['который', 'произойти', 'поэма', 'книга', 'дзян'],
#  ['тайна',
#   'доктрина',
#   'изложить',
#   'космогонический',
#   'идея',
#   'вечность',
#   'периодичность',
#   'бытие',
#   'иерархичность',
#   'план',
#   'смена',
#   'человеческий',
#   'животное'],
#  ['писать', 'статья', 'шахматный', 'тема', 'ежедневный', 'журнал'],
#  ['год', 'уезд', 'проживать', 'чел'],
#  ['год', 'выйти', 'издание', 'год', 'выдержать', 'издание'],
#  ['который',
#   'занимать',
#   'заметный',
#   'место',
#   'история',
#   'российский',
#   'фантастика'],
#  ['год'],
#  ['особенно',
#   'интересный',
#   'монументальный',
#   'панорама',
#   'второй',
#   'действие',
#   'который',
#   'критика',
#   'отмечать',
#   'тонкий',
#   'проникновение',
#   'поэтический',
#   'замысел',
#   'чайковский'],
#  ['петрония',
#   'путь',
#   'антверпен',
#   'владивосток',
#   'загореться',
#   'пассажир',
#   'пароход',
#   'западный',
#   'африканский',
#   'общество',
#   'петрония'],
#  ['рассматриваться', 'вопрос', 'являться', 'аграрный', 'россия', 'страна'],
#  ['август', 'интервью', 'уколов'],
#  ['век',
#   'российский_империя',
#   'век',
#   'дворцовый',
#   'переворот',
#   'женский',
#   'правление',
#   'определить',
#   'историк'],
#  ['военный',
#   'кафедра',
#   'фгбоу',
#   'камчатский',
#   'государственный',
#   'технический',
#   'университет',
#   'преобразовать',
#   'военный',
#   'учебный',
#   'центр'],
#  ['декабрь',
#   'год',
#   'композиция',
#   'секунда',
#   'услышать',
#   'волна',
#   'золотой',
#   'дождь',
#   'ранний'],
#  ['декабрь',
#   'назначить',
#   'место',
#   'последний',
#   'начальник',
#   'артиллерия',
#   'бугский',
#   'ингульский',
#   'днепровский',
#   'крепость',
#   'город',
#   'николаев'],
#  ['заметка', 'различный', 'тема', 'псевдоним', 'ultimate'],
#  ['апрель', 'год', 'двенадцатый', 'минута', 'матч'],
#  ['июнь',
#   'год',
#   'сравнивать',
#   'исповедь',
#   'лев',
#   'толстой',
#   'детство',
#   'детство',
#   'никита',
#   'однофамилец',
#   'польза',
#   'последний'],
#  ['летний', 'исламбек', 'год', 'передать', 'аренда', 'кокшетауский'],
#  ['май', 'год'],
#  ['ноябрь',
#   'год',
#   'город',
#   'калуга',
#   'новосибирск',
#   'строитель',
#   'фестиваль',
#   'стальной',
#   'натиск',
#   'festerguts',
#   'россия',
#   'калуга',
#   'stabror',
#   'россия',
#   'hidden',
#   'time',
#   'россия',
#   'balfor',
#   'россия',
#   'tessaract',
#   'украина',
#   'tremor',
#   'россия',
#   'beheaded',
#   'zombie',
#   'россия'],
#  ['сентябрь', 'полк', 'вести', 'бой', 'район', 'адамамуйж'],
#  ['июнь', 'год'],
#  ['май', 'год'],
#  ['государственный',
#   'русский',
#   'музей',
#   'санкт_петербург',
#   'эскиз',
#   'этюд',
#   'который',
#   'начать',
#   'писать',
#   'ещё',
#   'конец_xix',
#   'век'],
#  ['труд', 'императорский', 'вольный', 'экономический', 'общество'],
#  ['статья', 'русский', 'социологический', 'школа'],
#  ['семиреченский',
#   'казачий_войско',
#   'флаг',
#   'штандарт',
#   'казачий_войско',
#   'российский_империя',
#   'https',
#   'forma',
#   'odezhda'],
#  ['год', 'видный', 'перископ', 'небольшой', 'надстройка'],
#  ['музей', 'прикладной_искусство', 'москва'],
#  ['ранее', 'неофициальный', 'часть'],
#  ['надгробный', 'памятник', 'указать', 'неверный', 'год', 'рождение'],
#  ['новый',
#   'генеральный',
#   'продюсер',
#   'радио',
#   'назначить',
#   'бывший',
#   'журналист',
#   'ведущий',
#   'нтв'],
#  ['русский',
#   'степь',
#   'метод',
#   'исследование',
#   'растительный',
#   'покров',
#   'центральный',
#   'чернозёмный',
#   'степь'],
#  ['увеличивать',
#   'ломать',
#   'объём',
#   'портрет',
#   'фернанда',
#   'оливье',
#   'рассекать',
#   'плоскость',
#   'грань',
#   'продолжаться',
#   'пространство',
#   'который',
#   'считать',
#   'твёрдый',
#   'тело',
#   'неизбежно',
#   'ограниченный',
#   'плоскость',
#   'картина'],
#  ['громадный', 'большинство', 'знать', 'уточкин', 'спортсмен'],
#  ['точность', 'воспроизводить', 'картина', 'флавицкий'],
#  ['год', 'выиграть', 'этап', 'стать'],
#  ['который',
#   'цитата',
#   'страна',
#   'этот',
#   'тот',
#   'дикий',
#   'чудесный',
#   'тот',
#   'человек',
#   'это',
#   'найти'],
#  ['год'],
#  ['год', 'сариссофора', 'друг', 'македонский', 'боевой_порядок'],
#  ['год', 'гидроплан', 'вертолёт'],
#  ['который', 'опубликовать_статья', 'сологуба', 'еврейский', 'вопрос'],
#  ['также', 'проектор'],
#  ['год'],
#  ['глория', 'свенсон', 'исполнить', 'главный_роль'],
#  ['год', 'децисты', 'сформироваться', 'год', 'год', 'начало', 'профдискуссия'],
#  ['год'],
#  ['отойти',
#   'калигаризм',
#   'работать',
#   'сценарий',
#   'камерный',
#   'фильм',
#   'реалистический',
#   'драма',
#   'мещанский',
#   'среда'],
#  ['год', 'сыграть', 'китайский', 'горничная', 'ага', 'фаг'],
#  ['музыкант', 'открывать', 'портал', 'иной', 'мир'],
#  ['ряд', 'год', 'называться'],
#  ['год'],
#  ['арсенал',
#   'приём',
#   'добавиться',
#   'использование',
#   'негатив',
#   'ускоренный',
#   'гибкий',
#   'подготовка'],
#  ['писать', 'политический', 'экономический', 'тема'],
#  ['щётка', 'щётка', 'затрещать', 'трещотка'],
#  ['служащий',
#   'крупный',
#   'страховой',
#   'компания',
#   'питтсбург',
#   'коллекционер',
#   'художественный',
#   'который',
#   'принимать',
#   'самый',
#   'деятельный',
#   'участие',
#   'подготовка',
#   'переезд',
#   'фешина',
#   'америка'],
#  ['год',
#   'говориться',
#   'родство',
#   'человек',
#   'западный',
#   'внешность',
#   'кочевник',
#   'страна',
#   'сон'],
#  ['гога',
#   'палкин',
#   'поцелуй',
#   'мэри',
#   'пикфорд',
#   'никешка',
#   'пробуждаться',
#   'случайно',
#   'ильинский',
#   'выступать',
#   'изобретательно',
#   'легко',
#   'смешно'],
#  ['начать', 'выйти', 'ещё', 'официальный', 'регистрация', 'организация'],
#  ['русский', 'цинциннать'],
#  ['считаться',
#   'самый_влиятельный',
#   'работа',
#   'немой',
#   'кино',
#   'год',
#   'мурнау',
#   'погибнуть',
#   'автокатастрофа',
#   'одновременно',
#   'ufa',
#   'тот_иной',
#   'форма',
#   'зависимость',
#   'американский',
#   'компания',
#   'попасть',
#   'другой',
#   'немецкий',
#   'киностудия'],
#  ['который', 'следовать', 'ещё', 'несколько', 'успешный', 'фильм'],
#  ['также', 'отказываться', 'целиком', 'киноязык'],
#  ['совместно', 'пауль', 'кнеплерома'],
#  ['рассказывать',
#   'дорожный',
#   'полиция',
#   'который',
#   'совершать',
#   'неумышленный',
#   'убийство'],
#  ['раздел',
#   'role',
#   'computers',
#   'корреспондент',
#   'хартлить',
#   'патрисия',
#   'кирк',
#   'лессера',
#   'опубликовать',
#   'обзор',
#   'waxworks'],
#  ['консультант', 'главный', 'издательство', 'история', 'завод', 'год'],
#  ['некоторый', 'рассказ', 'впервые', 'опубликовать', 'журнал'],
#  ['улица', 'удача', 'который', 'номинировать_премия', 'оскар'],
#  ['который',
#   'впервые',
#   'опубликовать',
#   'августовский',
#   'номер',
#   'weird',
#   'tales',
#   'год'],
#  ['свойственно', 'амплуа', 'романтический', 'герой'],
#  ['симфония', 'симфония', 'два', 'часть'],
#  ['news', 'chronicle'],
#  ['поздний', 'также', 'фильм', 'морис', 'глёз', 'клуб', 'воздыхатель'],
#  ['сделать', 'римейк', 'название'],
#  ['частность', 'название', 'воронья', 'слободка'],
#  ['иметь', 'большой_успех', 'зритель'],
#  ['множество', 'другой', 'кинокомедия'],
#  ['называть', 'её', 'дикий'],
#  ['благодаря',
#   'который',
#   'сполянский',
#   'приобрести',
#   'всемирный',
#   'известность'],
#  ['герой',
#   'тот',
#   'угрожать',
#   'трон',
#   'азатот',
#   'находиться',
#   'сам',
#   'сердце',
#   'хаос'],
#  ['фильм', 'русский', 'тематика'],
#  ['запретить', 'март', 'год', 'цензура'],
#  ['выпустить',
#   'го',
#   'продать',
#   'телевизионный',
#   'коллекционер',
#   'телекомпания',
#   'guide',
#   'artists',
#   'productions',
#   'многие',
#   'цветной',
#   'фильм',
#   'печататься',
#   'черно',
#   'белый',
#   'плёнка',
#   'цветоделёный',
#   'негатив',
#   'утерять'],
#  ['месяц',
#   'май',
#   'десять',
#   'второй',
#   'оператор',
#   'последний',
#   'табор',
#   'весёлый',
#   'путешественник'],
#  ['писатель',
#   'эдвард',
#   'пикман',
#   'дерби',
#   'написать',
#   'сборник',
#   'азатот',
#   'другой',
#   'ужас'],
#  ['стать',
#   'центр',
#   'формирование',
#   'новый',
#   'индонезийский',
#   'культура',
#   'литература'],
#  ['председатель',
#   'экспертный',
#   'комитет',
#   'филологический',
#   'наука',
#   'всесоюзный',
#   'комитет',
#   'дело',
#   'высокий',
#   'школа',
#   'заместитель',
#   'академик',
#   'секретарь',
#   'отделение',
#   'литература',
#   'язык',
#   'ан_ссср',
#   'год'],
#  ['беломорско',
#   'балтийский',
#   'канал',
#   'имя_сталин',
#   'история',
#   'строительство'],
#  ['главный_герой',
#   'переодеваться',
#   'необычайно',
#   'быстро',
#   'лёгкий',
#   'некий',
#   'фреголь'],
#  ['год', 'этот', 'роман'],
#  ['год', 'однако', 'поздний', 'данный', 'эпизод', 'фильм', 'войти'],
#  ['также',
#   'номинироваться',
#   'оскар',
#   'игра',
#   'медицинский',
#   'драма',
#   'частный',
#   'мир',
#   'комедия',
#   'военный',
#   'время'],
#  ['госкиноиздат',
#   'рсфср',
#   'вследствие',
#   'сворачивание',
#   'политика',
#   'украинизация',
#   'прекратить',
#   'выпуск',
#   'украиноязычный',
#   'киноплакат'],
#  ['фильм',
#   'полёт',
#   'флэш',
#   'гордон',
#   'марс',
#   'криминальный',
#   'фильм_ужас',
#   'ночной',
#   'ключ',
#   'криминальный',
#   'комедия',
#   'чарли',
#   'чен',
#   'панама',
#   'комедия',
#   'незнакомец',
#   'город',
#   'фильм_нуар'],
#  ['карлофф',
#   'наоборот',
#   'демонический',
#   'преступник',
#   'жертва',
#   'медицинский',
#   'эксперимент',
#   'невинно',
#   'казнить',
#   'затем',
#   'врач',
#   'бенитёс',
#   'бомонт'],
#  ['режиссёр',
#   'григорий',
#   'александров',
#   'увидеть',
#   'вид',
#   'театральный',
#   'площадь',
#   'ресторан',
#   'крыша',
#   'отель',
#   'москва'],
#  ['журнал'],
#  ['считаться', 'хороший', 'произведение', 'писатель'],
#  ['другой', 'произведение'],
#  ['номинация'],
#  ['заглавный', 'роль', 'спектакль', 'уриэль', 'акоста'],
#  ['это',
#   'несерьёзно',
#   'менее',
#   'известный',
#   'амедео',
#   'надзаря',
#   'комедия',
#   'сто',
#   'тысяча_доллар'],
#  ['комедия', 'здоровье', 'мисс', 'бишоп', 'фильм_нуар'],
#  ['выступать', 'человек', 'который', 'разрушать', 'расистский', 'организация'],
#  ['пройтись', 'елисейский', 'поле', 'рассказывать', 'версаль'],
#  ['роль',
#   'который',
#   'принести',
#   'актёр',
#   'последний',
#   'карьера',
#   'номинация_премия'],
#  ['ботвинник',
#   'занять_место',
#   'выиграть',
#   'партия',
#   'алехин',
#   'капабланк',
#   'подтвердить',
#   'право',
#   'матч',
#   'чемпион_мир'],
#  ['год', 'бежать', 'италия'],
#  ['год',
#   'бывший',
#   'дом',
#   'австрийский',
#   'миссия',
#   'стать',
#   'гостевой',
#   'дом',
#   'немецкий',
#   'посольство',
#   'москва'],
#  ['роль', 'который', 'удостоить_премия', 'кинокритик'],
#  ['брат',
#   'орхидея',
#   'два',
#   'последний',
#   'фильм',
#   'главный_роль',
#   'исполнить',
#   'робинсон',
#   'богарт'],
#  ['роджерс', 'обрести', 'иной', 'облик'],
#  ['чёрно', 'белый', 'художественный_фильм', 'режиссёр', 'александр', 'роу'],
#  ['год', 'также', 'являться', 'часть', 'великий_отечественный', 'война'],
#  ['год',
#   'смысл',
#   'который',
#   'заключаться',
#   'отказ',
#   'план',
#   'создание',
#   'еврейский',
#   'государство',
#   'беженец',
#   'эцелый',
#   'перенести',
#   'деятельность',
#   'британский',
#   'объект'],
#  ['тень',
#   'тонкий',
#   'человек',
#   'военный',
#   'драма',
#   'боевой_действие',
#   'северный',
#   'атлантика',
#   'фильм_нуар'],
#  ['фильм',
#   'менее',
#   'являться',
#   'точный',
#   'её',
#   'экранизация',
#   'привносить',
#   'история',
#   'многие',
#   'новый',
#   'сцена',
#   'сюжетный',
#   'ход'],
#  ['посёлок', 'другой', 'также', 'роман', 'новелла'],
#  ['снять_фильм', 'оператор', 'постановщик', 'путь'],
#  ['человек', 'который', 'прийти', 'обед'],
#  ['сыграть_матч'],
#  ['также', 'криминальный', 'комедия'],
#  ['год',
#   'который',
#   'рекомендовать',
#   'предоставление',
#   'земля',
#   'аляска',
#   'временной',
#   'поселение',
#   'беженец',
#   'европейский',
#   'еврей',
#   'который',
#   'способствовать',
#   'преследование',
#   'сторона',
#   'нацист',
#   'время',
#   'великий_отечественный',
#   'война'],
#  ['многий', 'другой'],
#  ['который', 'создать', 'серия', 'одноимённый', 'роман', 'радиопрограмма'],
#  ['который', 'принести', 'её', 'номинация'],
#  ['остров',
#   'уэйк',
#   'давка',
#   'также',
#   'сыграть_главный',
#   'оскар',
#   'нуар',
#   'высокий',
#   'нуар'],
#  ['быть', 'богатый'],
#  ['человек', 'который', 'прийти', 'обед', 'кингс', 'роу'],
#  ['также', 'практикум', 'паразитический', 'простейшее', 'спирохета'],
#  ['роль', 'доктор', 'lanyon'],
#  ['главный_герой', 'режиссёр'],
#  ['который', 'последовать', 'серия', 'признанный', 'нуар', 'число'],
#  ['глаз', 'ночь', 'романтический', 'комедия', 'дорогой', 'рута', 'фильм_нуар'],
#  ['получить', 'ещё_один', 'номинация', 'оскар', 'комедия', 'верный', 'лишать'],
#  ['комедия', 'марджи', 'также', 'фильм_нуар'],
#  ['появиться',
#   'несколько',
#   'секунда',
#   'финал',
#   'вытащить',
#   'поезд',
#   'также',
#   'выступать',
#   'роль',
#   'человек',
#   'очередь',
#   'телефонный',
#   'будка'],
#  ['человек', 'который', 'прийти', 'ужин'],
#  ['соответственно'],
#  ['который', 'показать', 'мука', 'жена', 'связь', 'публично', 'жена'],
#  ['год', 'номинация'],
#  ['войти', 'самый_известный', 'повесть', 'медведь'],
#  ['кэтрин',
#   'хепбёрн',
#   'роль',
#   'успешный',
#   'уверенный',
#   'журналистка',
#   'вращаться',
#   'высокий',
#   'сфера',
#   'который',
#   'влюбляться',
#   'выходить_замуж',
#   'скромный',
#   'спортивный',
#   'репортёр'],
#  ['остальной', 'время', 'посвящать', 'свой', 'выступление', 'бродвей'],
#  ['также', 'собственный', 'фильм_нуар'],
#  ['который',
#   'бывший',
#   'заключить',
#   'фашистский',
#   'лагерь',
#   'время',
#   'гражданский_война',
#   'испания'],
#  ['март', 'год'],
#  ['номинация'],
#  ['война', 'северный', 'атлантика', 'никто', 'сбежать', 'отель', 'париж'],
#  ['выступать', 'дядя', 'племянница'],
#  ['год', 'лечь_основа', 'один', 'популярный', 'военный', 'песня'],
#  ['ряд', 'другой', 'картина'],
#  ['мисс', 'паркингтон', 'который', 'принести', 'второй', 'номинация'],
#  ['первый', 'бесспорный', 'фильм', 'принять', 'считать'],
#  ['закрытие',
#   'журнал',
#   'ленинградский',
#   'альманах',
#   'главный_редактор',
#   'ленинградский',
#   'отделение',
#   'издательство'],
#  ['роль',
#   'закадровый',
#   'противник',
#   'выступать',
#   'находиться',
#   'соседство',
#   'ферма',
#   'фоксвуд',
#   'пинчфилд',
#   'каждый',
#   'который',
#   'скотный',
#   'двор',
#   'враждовать',
#   'определённый',
#   'время',
#   'два',
#   'одновременно'],
#  ['продюсер', 'её', 'сам', 'значимый', 'фильм'],
#  ['который',
#   'рассказывать',
#   'жизнь',
#   'семья',
#   'глава',
#   'который',
#   'уйти',
#   'служить',
#   'война'],
#  ['криминальный', 'фильм', 'фильм_нуар'],
#  ['конец',
#   'неделя',
#   'её',
#   'карьера',
#   'постепенно',
#   'начало',
#   'идти',
#   'спад',
#   'частый',
#   'конфликт',
#   'актёр',
#   'управлять',
#   'киностудия'],
#  ['пользоваться',
#   'большой_популярность',
#   'советский',
#   'кинозритель',
#   'год',
#   'война'],
#  ['романтический',
#   'комедия',
#   'райский',
#   'тело',
#   'комедия',
#   'расти',
#   'нежный',
#   'виноград',
#   'фильм_нуар'],
#  ['сын', 'лесси', 'годовалый', 'прежде', 'сыграть_главный', 'оскар'],
#  ['это',
#   'лишь',
#   'вопрос',
#   'время',
#   'прежде',
#   'другой',
#   'история',
#   'марлоу',
#   'получить',
#   'отражение',
#   'экран'],
#  ['обладатель', 'балканский', 'чемпионат', 'состав', 'национальный_сборная'],
#  ['также', 'немного', 'менее', 'успешный'],
#  ['который',
#   'ллойда',
#   'нолан',
#   'также',
#   'сыграть_роль',
#   'инспектор',
#   'фбр',
#   'бриггс'],
#  ['зелёный', 'огонь', 'imdb'],
#  ['капитан', 'полиция', 'фильм_нуар'],
#  ['который', 'сделать', 'звезда'],
#  ['который',
#   'самый',
#   'независимый',
#   'фильм',
#   'ланга',
#   'год',
#   'карьера',
#   'сша',
#   'продюсер',
#   'никой',
#   'образ',
#   'влиять',
#   'работа',
#   'mcgilligan',
#   'patrick',
#   'fritz',
#   'lang',
#   'nature',
#   'beast'],
#  ['однако', 'это', 'принцип', 'роль', 'сыграть_главный'],
#  ['похоронить',
#   'случайно',
#   'денежный',
#   'безумие',
#   'бомонт',
#   'известный',
#   'роль',
#   'детектив',
#   'майкл',
#   'шейный',
#   'который',
#   'сыграть',
#   'четыре',
#   'фильм',
#   'год'],
#  ['фильм', 'борис', 'бабочкин', 'анатолий', 'босулаев'],
#  ['также', 'важный_роль', 'фильм'],
#  ['также', 'библейский', 'драма'],
#  ['также', 'год', 'седло'],
#  ['который', 'беспринципный', 'газетный', 'репортёр'],
#  ['предстать', 'образ', 'лейтенант', 'полиция'],
#  ['год', 'ранее'],
#  ['выдающийся', 'пара', 'криминальный', 'драма'],
#  ['музыкальный', 'комедия', 'ночной', 'песня', 'фильм_нуар'],
#  ['одновременно', 'стать', 'продюсер', 'такой', 'фильм_нуар'],
#  ['тейлор',
#   'сыграть',
#   'успешный',
#   'адвокат',
#   'который',
#   'ревность',
#   'убивать',
#   'невеста',
#   'тот',
#   'решать',
#   'уйти',
#   'другой'],
#  ['также', 'семейный', 'драма', 'помнить', 'мама'],
#  ['который',
#   'броудить',
#   'сыграть',
#   'один',
#   'свой',
#   'главный_роль',
#   'карьера',
#   'создать',
#   'образ',
#   'стив',
#   'рэндалл',
#   'ветеран',
#   'война',
#   'который',
#   'стать',
#   'водитель',
#   'собственный',
#   'грузовик',
#   'недавно',
#   'жениться'],
#  ['который',
#   'сделать',
#   'попытка',
#   'расположить',
#   'гангстерский',
#   'жанр',
#   'реалия',
#   'послевоенный',
#   'жизнь'],
#  ['основа',
#   'который',
#   'также',
#   'лежать',
#   'сюжет',
#   'национальный',
#   'ненависть'],
#  ['год',
#   'создать',
#   'архивный',
#   'съёмка',
#   'сделать',
#   'участник',
#   'путешествие'],
#  ['некоторый', 'другой'],
#  ['первый', 'легион', 'прежде', 'год', 'завершить', 'актёрский_карьера'],
#  ['лоринг',
#   'сыграть_главный',
#   'женский',
#   'роль',
#   'невеста',
#   'подставить',
#   'убийство',
#   'главное_герой',
#   'который',
#   'вместе',
#   'шурин',
#   'находить',
#   'настоящий',
#   'преступник'],
#  ['студия'],
#  ['режиссёр', 'номинировать', 'оскар', 'imdb'],
#  ['сыграть', 'такой', 'успешный', 'фильм_нуар'],
#  ['сегодня', 'считаться', 'определять', 'фильм', 'направление'],
#  ['поздний',
#   'запомниться',
#   'качество_режиссёр',
#   'актёр',
#   'такой',
#   'фильм',
#   'крик',
#   'мщение'],
#  ['также', 'нечистый', 'рука', 'родственник', 'владелец', 'казино'],
#  ['также', 'номинантка', 'премия', 'номинация'],
#  ['также', 'роль', 'крутой', 'главный_герой', 'фильм_нуар'],
#  ['также', 'фильм_нуар'],
#  ['номинация'],
#  ['выдавать', 'самый', 'запоминаться', 'игра'],
#  ['год', 'издательство'],
#  ['де',
#   'корсия',
#   'сыграть',
#   'грабитель',
#   'безжалостный',
#   'убийца',
#   'вилли',
#   'гарзах',
#   'бывший',
#   'борец',
#   'который',
#   'любить',
#   'выступать',
#   'губный',
#   'гармошка'],
#  ['множество', 'имитация'],
#  ['капра', 'столкнуться', 'серьёзный', 'финансовый_проблема'],
#  ['мосс',
#   'сыграть',
#   'генерал',
#   'командир',
#   'хозе',
#   'который',
#   'влюбить',
#   'заглавный',
#   'героиня'],
#  ['начинаться', 'убийство', 'медиамагнат'],
#  ['однако',
#   'год',
#   'перейти',
#   'лёгкое',
#   'жанр',
#   'поставить',
#   'серия',
#   'популярный',
#   'комедия',
#   'комедия',
#   'число'],
#  ['рассказывать', 'газетный', 'репортёр', 'джим', 'макнил'],
#  ['журнал',
#   'сельмашевец',
#   'советский',
#   'белоруссия',
#   'заведовать_отдел',
#   'поэзия',
#   'журнал'],
#  ['главный_редактор', 'журнал'],
#  ['также', 'вестерн'],
#  ['также', 'музыкальный', 'комедия'],
#  ['также',
#   'культовый',
#   'приключенческий',
#   'фильм',
#   'мозг',
#   'донован',
#   'авторитет',
#   'медленно',
#   'неуклонно',
#   'расти'],
#  ['сыграть',
#   'который',
#   'симпатизировать',
#   'жена',
#   'детектив',
#   'её',
#   'просьба',
#   'предлагать',
#   'детектив',
#   'безопасный',
#   'выгодный',
#   'работа',
#   'один',
#   'свой',
#   'компания'],
#  ['предел', 'закон', 'фальшивый', 'деньга'],
#  ['музыкальный', 'фильм'],
#  ['режиссёр', 'поставить', 'такой', 'фильм'],
#  ['научно_фантастический',
#   'драма',
#   'ураган',
#   'слэттери',
#   'также',
#   'фильм_нуар'],
#  ['романтический',
#   'комедия',
#   'человек',
#   'быть',
#   'судачить',
#   'также',
#   'фильм_нуар'],
#  ['магазин', 'пересечение', 'экспресс', 'декабрь', 'год'],
#  ['аленький', 'цветочек', 'также', 'шедевр'],
#  ['также', 'фильм_нуар'],
#  ['также', 'сыграть_главный', 'женский', 'классический', 'фильм'],
#  ['вермилья',
#   'сыграть',
#   'значимый',
#   'роль',
#   'мудрый',
#   'уравновесить',
#   'владелец',
#   'издательство',
#   'дядя',
#   'беспринципный',
#   'коварный',
#   'главный_героиня'],
#  ['главный',
#   'действовать',
#   'лицо',
#   'являться',
#   'ветеран',
#   'великий_отечественный',
#   'война',
#   'imdb'],
#  ['предел', 'закон'],
#  ['многий', 'другой', 'imdb'],
#  ['шаг', 'эшафот', 'поздний', 'сыграть', 'такой', 'заметный', 'картина'],
#  ['макнэлли',
#   'исполнить',
#   'важный_роль',
#   'главное',
#   'врач',
#   'отделение',
#   'муниципальный',
#   'больница',
#   'который',
#   'оказать',
#   'поддержка',
#   'начинающий',
#   'чёрнокожий',
#   'коллега'],
#  ['роль', 'который', 'принести', 'премия'],
#  ['вновь', 'закарий', 'скотт'],
#  ['стать',
#   'неофициальный',
#   'гимн',
#   'киев',
#   'мелодия',
#   'припев',
#   'позывной',
#   'сигнал',
#   'киевский',
#   'радио'],
#  ['этот',
#   'картина',
#   'относиться',
#   'относительно',
#   'небольшой',
#   'число',
#   'лондонский',
#   'нуар',
#   'действие',
#   'который',
#   'происходить',
#   'лондон'],
#  ['также', 'фильм_нуар'],
#  ['сыграть',
#   'важный_роль',
#   'сельский',
#   'шериф',
#   'который',
#   'вести',
#   'охота',
#   'опасный',
#   'гангстер'],
#  ['поздний'],
#  ['тереза', 'ракен', 'роман', 'эмиль', 'золя', 'конец', 'неделя', 'порог'],
#  ['известный',
#   'свой',
#   'вклад',
#   'нуаровыя',
#   'жанр',
#   'благодаря',
#   'такой',
#   'картина'],
#  ['считаться',
#   'неоклассический',
#   'хотя',
#   'написать',
#   'серийный',
#   'год',
#   'совершенно',
#   'иной',
#   'язык',
#   'нежели',
#   'опера',
#   'пульчинелла'],
#  ['фильм'],
#  ['также', 'военный', 'фильм'],
#  ['брэнд',
#   'сыграть',
#   'бойд',
#   'кейный',
#   'один',
#   'два',
#   'уголовник',
#   'который',
#   'уволить',
#   'капитан',
#   'полиция',
#   'тимоти',
#   'бэйль'],
#  ['джина', 'выступить', 'сорежиссёр', 'донить', 'также'],
#  ['министр_оборона', 'сша', 'захватчик', 'марс', 'армейский', 'офицер'],
#  ['год', 'время', 'исполнение', 'который', 'играться', 'звук'],
#  ['исполнить_роль',
#   'доктор',
#   'который',
#   'гибнуть',
#   'автокатастрофа',
#   'опрометчивый',
#   'вождение',
#   'друг',
#   'коллега'],
#  ['макнэлли',
#   'представать',
#   'роль',
#   'зловещий',
#   'австрийский',
#   'граф',
#   'владение',
#   'который',
#   'британский',
#   'джентльмен',
#   'вести',
#   'розыск',
#   'свой',
#   'пропасть',
#   'друг'],
#  ['писатель',
#   'говорить',
#   'отразить',
#   'тот',
#   'тема',
#   'который',
#   'владеть',
#   'море',
#   'рыбный',
#   'рыбный',
#   'рыбак',
#   'стать',
#   'подробно',
#   'останавливаться',
#   'книга',
#   'получиться',
#   'неоправданно',
#   'объёмный',
#   'художественный',
#   'точка_зрение'],
#  ['рассказывать',
#   'бывший',
#   'гангстер',
#   'питер',
#   'грэй',
#   'джон',
#   'расселла',
#   'который',
#   'возвращаться',
#   'война',
#   'герой',
#   'пытаться',
#   'встать',
#   'честный',
#   'путь',
#   'бывший',
#   'сообщник',
#   'намеренно',
#   'подставлять',
#   'власть',
#   'главарь',
#   'преступный',
#   'синдикат'],
#  ['выступать', 'который', 'отслужить', 'срочный', 'военный_служба'],
#  ['также', 'её', 'сам', 'знаменитый', 'фильм'],
#  ['гудение',
#   'свист',
#   'звон',
#   'гул',
#   'войти',
#   'серия',
#   'фильм',
#   'музыкальный_инструмент'],
#  ['прийти', 'проба', 'порог', 'заявить', 'сниматься', 'хватить', 'разврат'],
#  ['человек', 'тень', 'также', 'участие', 'чандлера'],
#  ['роль', 'альф', 'роль', 'модель', 'танцовщица'],
#  ['самый',
#   'убедительный',
#   'доносить',
#   'сдержанный',
#   'облик',
#   'сила',
#   'воспринимать',
#   'настоящий',
#   'отличный',
#   'исполнитель'],
#  ['монета',
#   'фонтан',
#   'неизвестный_причина',
#   'сломать',
#   'копьё',
#   'человек',
#   'имя',
#   'питер'],
#  ['также', 'военный', 'фильм'],
#  ['также', 'номинация', 'оскар', 'фильм'],
#  ['который',
#   'опираться',
#   'психологический',
#   'исследование',
#   'оценивать',
#   'влияние',
#   'сегрегация',
#   'учиться',
#   'школа'],
#  ['казахстанский', 'клуб', 'алма_ата'],
#  ['который', 'произвести', 'продюсерский_компания', 'лупино', 'филмейкерс'],
#  ['салливана',
#   'сыграть',
#   'выпить',
#   'банковский',
#   'кассир',
#   'майк',
#   'донован',
#   'ошибочно',
#   'заподозрить',
#   'кража',
#   'обнаруживать',
#   'недостача',
#   'тысяча_доллар'],
#  ['строиться',
#   'вокруг',
#   'герой',
#   'героиня',
#   'случайно',
#   'увидеть',
#   'окно',
#   'преступление'],
#  ['это', 'случиться', 'мэри'],
#  ['поздний', 'сыграть', 'ремейк', 'классический', 'нуар'],
#  ['также', 'вестерн'],
#  ['также',
#   'комедия',
#   'тайна',
#   'мюзикл',
#   'увидеть',
#   'свой',
#   'сон',
#   'фильм_ужас'],
#  ['также', 'новелизация', 'фильм'],
#  ['который',
#   'взять',
#   'обязанность',
#   'продюсер',
#   'режиссёр',
#   'исполнитель',
#   'главный_роль'],
#  ['сыграть_главный', 'роль', 'другой'],
#  ['год',
#   'страсберг',
#   'предложить',
#   'главный_роль',
#   'бродвейский',
#   'спектакль',
#   'дневник',
#   'анна',
#   'франк',
#   'который',
#   'принести',
#   'номинация'],
#  ['джонни', 'тремейн', 'последний', 'поезд', 'ганна', 'хилла'],
#  ['многий', 'другой', 'imdb'],
#  ['проклятый',
#   'гражданин',
#   'фройляйн',
#   'дело',
#   'против',
#   'бруклин',
#   'хороший',
#   'день',
#   'повешение'],
#  ['стать',
#   'сам',
#   'убедительный',
#   'попытка',
#   'основа',
#   'существующий',
#   'научный',
#   'знание',
#   'свой',
#   'время',
#   'максимально',
#   'правдоподобно',
#   'представить',
#   'полёт',
#   'космический_корабль',
#   'марс',
#   'затем',
#   'попытка',
#   'экипаж',
#   'вернуться',
#   'назад'],
#  ['статья', 'первый', 'страница'],
#  ['фигурировать',
#   'название',
#   'столичный',
#   'птица',
#   'мясной',
#   'мясной',
#   'мясной',
#   'также',
#   'краткий',
#   'энциклопедия',
#   'домашний',
#   'хозяйство'],
#  ['хьюстонский',
#   'история',
#   'разоблачение',
#   'майами',
#   'новый',
#   'орлеан',
#   'тьма',
#   'убийство',
#   'шестой',
#   'авеню',
#   'разоблачение',
#   'портланд'],
#  ['затем', 'научный', 'пресса', 'член', 'коллегия', 'наука', 'журнал'],
#  ['идея', 'двойник', 'пример', 'служить', 'фильм_нуар'],
#  ['многий', 'другой', 'imdb'],
#  ['сатанинский', 'администратор', 'дом'],
#  ['убийство', 'шестой', 'авеню', 'также', 'фантастический', 'драма'],
#  ['который', 'принести', 'номинация'],
#  ['удаться',
#   'передать',
#   'паранойя',
#   'холодный',
#   'война',
#   'атмосферный',
#   'жуткий',
#   'экранный',
#   'образ',
#   'пришелец',
#   'пытаться',
#   'захватить',
#   'мир'],
#  ['эпизод',
#   'год',
#   'сыграть',
#   'комедия',
#   'мальчик',
#   'зелёный',
#   'волос',
#   'джекпот',
#   'фильм_нуар'],
#  ['эпизод_сериал', 'карузый', 'сыграть', 'различный', 'роль'],
#  ['год', 'минута'],
#  ['съёмка',
#   'организовать',
#   'танцевальный',
#   'вечеринка',
#   'свой',
#   'друг',
#   'университет',
#   'её',
#   'начало',
#   'договориться',
#   'банда',
#   'местный',
#   'хулиган',
#   'вторжение',
#   'территория',
#   'университет',
#   'нужный',
#   'момент',
#   'начать',
#   'драка'],
#  ['безумный', 'шайо'],
#  ['долгожданный',
#   'ночь',
#   'также',
#   'исполнить',
#   'ряд',
#   'роль',
#   'несколько',
#   'сериал'],
#  ['другой'],
#  ['кит',
#   'исполнить_роль',
#   'один',
#   'два',
#   'бандит',
#   'который',
#   'охотиться',
#   'похитить',
#   'деньга',
#   'случайно',
#   'оказаться',
#   'дизайнер'],
#  ['человек',
#   'вход',
#   'встречать',
#   'трубач',
#   'время',
#   'сцена',
#   'ярмарка',
#   'зал',
#   'зала',
#   'расхаживать',
#   'цыганка',
#   'фокусник'],
#  ['повествоваться',
#   'пехотинец',
#   'который',
#   'война',
#   'попадать',
#   'наш',
#   'время'],
#  ['правительство',
#   'иметь',
#   'монополия',
#   'последний',
#   'экземпляр',
#   'давно',
#   'изобрести',
#   'хроноскоп',
#   'также',
#   'собранный',
#   'секрет',
#   'принцип',
#   'действие',
#   'контролировать',
#   'научный',
#   'исследование',
#   'смежный',
#   'область',
#   'никто',
#   'заново',
#   'изобрести',
#   'построить'],
#  ['часть', 'westinghouse', 'desilu', 'wm'],
#  ['руководитель', 'городской', 'писательский', 'организация'],
#  ['также', 'фильм_нуар'],
#  ['основа', 'который', 'положить', 'роман', 'дональд', 'гамильмтон', 'год'],
#  ['год',
#   'выпуск',
#   'бюджет',
#   'доллар',
#   'затрагивать',
#   'такой',
#   'острый',
#   'тема',
#   'страх',
#   'смерть'],
#  ['который', 'принести', 'номинация'],
#  ['референт',
#   'отдел',
#   'литература_искусство',
#   'также',
#   'популярный',
#   'журнал',
#   'вопрос',
#   'литература',
#   'дружба',
#   'народ',
#   'год',
#   'редактор_журнал',
#   'редактор_журнал'],
#  ['год', 'директор', 'областной', 'историко', 'краеведческий_музей', 'гбао'],
#  ['сестрёнка', 'хау', 'получить', 'главный', 'награда'],
#  ['произойти', 'тот', 'история'],
#  ['снять', 'район', 'ньюмена', 'пассаж', 'рэтбоун', 'стрит'],
#  ['номинация', 'самый', 'многообещающий', 'новичок', 'среди_женщина'],
#  ['выполнить',
#   'основа',
#   'анализ',
#   'фотография',
#   'космический',
#   'аппарат',
#   'луна',
#   'октябрь',
#   'год'],
#  ['вплоть'],
#  ['жизнь', 'австралийский', 'фермер'],
#  ['приключение',
#   'четыре',
#   'французский',
#   'солдат',
#   'немецкий',
#   'пленник',
#   'африканский',
#   'пустыня',
#   'время',
#   'великий_отечественный',
#   'война'],
#  ['добавить', 'кой'],
#  ['персонаж',
#   'бельмондо',
#   'пришелец',
#   'домой',
#   'успеть',
#   'телепоказ',
#   'фильм',
#   'последний',
#   'дыхание'],
#  ['саркастически',
#   'высмеивать',
#   'два',
#   'незадачливый',
#   'фарцовщик',
#   'стать',
#   'жертва',
#   'советский',
#   'журналист',
#   'который',
#   'выдать',
#   'американец'],
#  ['эпизод',
#   'который',
#   'жена',
#   'барбара',
#   'хейл',
#   'иметь',
#   'постоянный',
#   'роль',
#   'секретарь',
#   'главное_герой',
#   'также',
#   'женщина',
#   'полиция',
#   'эпизод'],
#  ['написать',
#   'основа',
#   'материал',
#   'улисс',
#   'отдельный',
#   'работа',
#   'сам',
#   'композитор'],
#  ['сыграть',
#   'модить',
#   'эткинсон',
#   'широко',
#   'шагать',
#   'её',
#   'персонаж',
#   'проститутка',
#   'джина',
#   'хакер'],
#  ['др',
#   'год',
#   'также',
#   'предпринять_попытка',
#   'организовать',
#   'прокат',
#   'автомашина',
#   'житель',
#   'увенчаться',
#   'успех'],
#  ['который', 'рассматриваться', 'фактический', 'ответ', 'профиль', 'мужество'],
#  ['роль', 'взять', 'мотивировать', 'это', 'похожий', 'военный', 'человек'],
#  ['перевод', 'название', 'первый', 'фильм', 'бернардо', 'бертолуччи'],
#  ['однако',
#   'включать',
#   'восхитительный',
#   'смесь',
#   'виртуозный',
#   'мастерство',
#   'аффектация'],
#  ['роль', 'либерти', 'вэланс'],
#  ['сниматься',
#   'формат',
#   'затем',
#   'помощь',
#   'оптический',
#   'печать',
#   'перевести',
#   'трёхплёночный',
#   'формат',
#   'синерама'],
#  ['включая', 'последний', 'решающий', 'эпизод', 'многолетний', 'сериал'],
#  ['также',
#   'второстепенный_роль',
#   'другой',
#   'известный',
#   'британский',
#   'американский',
#   'фильм',
#   'включая'],
#  ['номинировать', 'оскар', 'роль', 'комедия'],
#  ['создать',
#   'воспоминание',
#   'учёба',
#   'военный',
#   'академия',
#   'представлять',
#   'протест',
#   'против',
#   'жестокость',
#   'насилие'],
#  ['компания'],
#  ['стеклер',
#   'отложить',
#   'выход',
#   'свой',
#   'фильм',
#   'чувствовать',
#   'приоритет',
#   'двойной',
#   'билет',
#   'достаться',
#   'садист'],
#  ['отличаться',
#   'ещё',
#   'режиссёрский',
#   'работа',
#   'поэтичный',
#   'режиссура',
#   'однако',
#   'получить',
#   'тот',
#   'оценка'],
#  ['принести', 'награда'],
#  ['год', 'ответственный_секретарь', 'журнал'],
# ...
#   'исполнить',
#   'главный_роль'],
#  ['главный_редактор',
#   'томный',
#   'антология',
#   'японский',
#   'литература',
#   'член_правление',
#   'мегапроект',
#   'пушкинский',
#   'библиотека'],
#  ['роль', 'зак', 'дилла'],
#  ['год', 'алисий', 'выступать', 'актёр', 'кэт', 'грин'],
#  ['год', 'эпизод', 'подстава'],
#  ['год',
#   'оппозиция',
#   'взять',
#   'контроль',
#   'большинство',
#   'консервативный',
#   'северный',
#   'округ',
#   'заменить',
#   'многий',
#   'консервативный',
#   'демократ',
#   'оппозиция'],
#  ['год', 'каменный', 'джунгли', 'год'],
#  ['настоящий_время', 'профессор'],
#  ['посредством',
#   'приём',
#   'сатирический',
#   'абсурд',
#   'рассматриваться',
#   'идея',
#   'сверхценность',
#   'детство',
#   'характерный',
#   'творчество',
#   'крапивина',
#   'отчасти',
#   'пародировать',
#   'образ'],
#  ['продать',
#   'экземпляр',
#   'издание',
#   'десять',
#   'стих',
#   'рассказывать',
#   'правда',
#   'любовь'],
#  ['сходный', 'свой', 'гордиться', 'финал'],
#  ['сыграть', 'тренер', 'призываться', 'володя', 'ларин'],
#  ['журнал'],
#  ['также', 'хитрый', 'крестьянин', 'комедия'],
#  ['номинация_хороший',
#   'исполнение',
#   'молодой',
#   'актёр',
#   'комедийный',
#   'сериал',
#   'роль',
#   'элизабет',
#   'уокфилд',
#   'сериал',
#   'sweet',
#   'valley',
#   'high'],
#  ['эдди',
#   'пейдж',
#   'выступить',
#   'качество',
#   'продюсер',
#   'исполнитель',
#   'несколько',
#   'роль'],
#  ['год',
#   'стать',
#   'хит',
#   'германия',
#   'принести',
#   'первый',
#   'четыре',
#   'номинация_премия'],
#  ['год', 'октябрь', 'зимний', 'шина', 'izen', 'ii', 'анонсировать'],
#  ['артхаусный', 'шедевр'],
#  ['который',
#   'дрейфус',
#   'вновь',
#   'выдвинуть',
#   'премия',
#   'американский',
#   'соискание'],
#  ['божественный',
#   'тайна',
#   'сестричка',
#   'последний',
#   'который',
#   'также',
#   'реж'],
#  ['два', 'сиквел'],
#  ['который', 'сам', 'написать_сценарий'],
#  ['который',
#   'также',
#   'социально',
#   'сознательный',
#   'получить',
#   'смешанный',
#   'положительный_отзыв'],
#  ['песня', 'использоваться', 'центральный', 'музыкальный', 'тема', 'фильм'],
#  ['стоить', 'намного', 'дорогой', 'оказаться', 'коммерчески', 'удачный'],
#  ['год',
#   'состояться',
#   'появление',
#   'ричардс',
#   'весь',
#   'остальной',
#   'фантастический',
#   'четвёрка',
#   'серия',
#   'fantastic',
#   'fortitude'],
#  ['город', 'близнец', 'музыка', 'время', 'луназ', 'трансплантант'],
#  ['коллекция', 'экспозиция', 'камера', 'камера'],
#  ['роль', 'гортензия', 'кьюмбербатч', 'который', 'номинировать_премия'],
#  ['затем', 'воплотить', 'роль', 'алкоголик', 'шенкса', 'картина'],
#  ['получить',
#   'мировой',
#   'признание',
#   'создание',
#   'фантастический',
#   'трилогия'],
#  ['отмечать',
#   'высокий',
#   'измождённый',
#   'твёрдый',
#   'старый',
#   'кость',
#   'бледный',
#   'молоко',
#   'плоть',
#   'глаз',
#   'глубокий',
#   'голубой',
#   'любой',
#   'человеческий',
#   'глаз',
#   'жёлтый',
#   'который',
#   'гореть',
#   'лёд'],
#  ['полностью',
#   'вымышленный',
#   'опытно',
#   'проектный',
#   'работа',
#   'создание',
#   'танк',
#   'воздушный',
#   'подушка',
#   'попытка',
#   'саботаж',
#   'являться',
#   'сюжетный',
#   'фон',
#   'основный',
#   'действие'],
#  ['роль', 'другой', 'фильм', 'сериал'],
#  ['офф',
#   'офф',
#   'главное',
#   'госпиталь',
#   'также',
#   'отойти',
#   'стандарт',
#   'сделать',
#   'акцент',
#   'сюжет',
#   'ужас'],
#  ['роль', 'майкл', 'болтон', 'фильм'],
#  ['вообще',
#   'долгий_время',
#   'оставаться',
#   'самый',
#   'кассовый',
#   'фильм',
#   'история'],
#  ['память',
#   'летие',
#   'минюст',
#   'россия',
#   'год',
#   'мвд',
#   'россия',
#   'крепость',
#   'боевой',
#   'содружество'],
#  ['год',
#   'вновь',
#   'показать',
#   'зритель',
#   'джулия',
#   'робертс',
#   'её',
#   'полюбить',
#   'ироничный',
#   'комедиантка',
#   'заразительный',
#   'смех',
#   'широкий',
#   'улыбка'],
#  ['год',
#   'исполнить',
#   'двойной',
#   'роль',
#   'деревенский',
#   'красавица',
#   'начинающий',
#   'актёр'],
#  ['год',
#   'улица',
#   'гришин',
#   'белинский',
#   'односторонний',
#   'движение',
#   'ул',
#   'крупский',
#   'больший',
#   'разворотный',
#   'кольцо',
#   'конец',
#   'линия',
#   'конец',
#   'год',
#   'кольцо',
#   'демонтировать',
#   'также',
#   'новый',
#   'разворотный',
#   'кольцо',
#   'облгаз',
#   'проспект',
#   'шмидт'],
#  ['который', 'задействовать', 'практически', 'свободный', 'павильон'],
#  ['неоднократно', 'награждаться', 'мастерство', 'хореограф'],
#  ['связать', 'смоленский', 'кладбище'],
#  ['слава', 'прибавлять'],
#  ['сниматься', 'эпизод'],
#  ['снять', 'отношение', 'виктория'],
#  ['стать_обладатель',
#   'специальный',
#   'награда',
#   'жюри',
#   'кинофестиваль',
#   'неигровой',
#   'кино',
#   'россия'],
#  ['создатель', 'участник', 'группа'],
#  ['главный',
#   'режиссёр',
#   'санкт_петербургский',
#   'филиал',
#   'вгтрк',
#   'работать',
#   'арт',
#   'директор',
#   'трк'],
#  ['картер', 'хортон', 'фильм'],
#  ['главный_редактор', 'родоначальник', 'сайт', 'сэ', 'журнал'],
#  ['роль',
#   'дебби',
#   'торнберри',
#   'также',
#   'озвучивать',
#   'роль',
#   'сиерра',
#   'сериал'],
#  ['ведущий_программа'],
#  ['место', 'номинация', 'рассказ'],
#  ['костюмер',
#   'выступить',
#   'художник',
#   'костюм',
#   'студия',
#   'мосфильм',
#   'нелли',
#   'фомин'],
#  ['английский', 'судья'],
#  ['также',
#   'пожалеть',
#   'запрет',
#   'фильм',
#   'попасть',
#   'фильм',
#   'любой',
#   'западный',
#   'фестиваль',
#   'конец',
#   'наверняка',
#   'стать',
#   'такой',
#   'триумфатор'],
#  ['который', 'оператор'],
#  ['честь', 'высказывание', 'бивена'],
#  ['персонаж'],
#  ['затем', 'последовать', 'фильм'],
#  ['предложить', 'режиссёр', 'кандидатура', 'стейтема', 'один', 'оскар'],
#  ['прежде', 'объявить', 'свой', 'уход', 'лето', 'год'],
#  ['также',
#   'считать',
#   'фильм',
#   'антология',
#   'основной',
#   'сюжетный_линия',
#   'вращаться',
#   'вокруг',
#   'различный',
#   'владелец',
#   'дорога',
#   'фортепиано',
#   'xvi_век'],
#  ['который', 'принести', 'четыре', 'премия', 'эмми', 'четыре'],
#  ['автор',
#   'рассматривать',
#   'история',
#   'молоно',
#   'тойня',
#   'произведение',
#   'народный',
#   'тибетский',
#   'повествовать',
#   'праведник',
#   'молоно',
#   'тойна',
#   'отправиться',
#   'ад',
#   'поиск',
#   'мать'],
#  ['также', 'фильм_ужас'],
#  ['негативно', 'оценить', 'критик', 'провалиться', 'прокат'],
#  ['год', 'номинация_хороший', 'драматический', 'действие'],
#  ['роль', 'который', 'актёр', 'вновь', 'номинироваться', 'премия', 'ариэль'],
#  ['выступать', 'роль', 'уиллард', 'кейтс', 'сериал'],
#  ['флинна', 'карсен', 'серия', 'фильм'],
#  ['минобороны',
#   'российский_федерация',
#   'почётный_грамота',
#   'мэр',
#   'москва',
#   'почётный',
#   'знак',
#   'российский_академия',
#   'физико_математический',
#   'рыцарь',
#   'наука',
#   'искусство'],
#  ['слово', 'музыка', 'обречь', 'стать', 'звезда'],
#  ['август',
#   'год',
#   'мфк',
#   'сибиряк',
#   'ознакомить',
#   'болельщик',
#   'ценовой',
#   'политика',
#   'билет',
#   'сезон',
#   'матч',
#   'рубль',
#   'зависимость',
#   'категория',
#   'матч',
#   'абонемент',
#   'рубль'],
#  ['апрель', 'год', 'вступить', 'служба'],
#  ['апрель', 'год', 'который', 'выйти', 'русский', 'ненецкий', 'язык'],
#  ['го', 'ноябрь', 'выступить', 'поход', 'доставить'],
#  ['декабрь', 'год'],
#  ['апрель', 'год'],
#  ['длина', 'основный', 'пролёт', 'пролёт', 'мост', 'китай'],
#  ['ноябрь', 'год'],
#  ['ноябрь', 'год', 'вызвать', 'широкий', 'общественный', 'резонанс'],
#  ['сентябрь', 'год'],
#  ['сентябрь', 'полк', 'вести', 'бой', 'район', 'село', 'масберза'],
#  ['май',
#   'год',
#   'умудриться',
#   'получить',
#   'первый',
#   'жёлтый',
#   'карточка',
#   'пятый',
#   'секунда',
#   'матч'],
#  ['май',
#   'год',
#   'континентальный',
#   'хоккейный_лига',
#   'сформировать',
#   'тренеский',
#   'бригада',
#   'команда',
#   'матч',
#   'звезда',
#   'премьер_лига'],
#  ['grupo',
#   'de',
#   'caça',
#   'da',
#   'força',
#   'aérea',
#   'brasileira',
#   'истребительный',
#   'эскадрилья',
#   'ввс',
#   'бразилия',
#   'совершить',
#   'общий_сложность',
#   'боевой',
#   'вылет',
#   'получить',
#   'который',
#   'резервный',
#   'самолёт'],
#  ['tv', 'ru', 'март', 'год', 'елена', 'николаев'],
#  ['апрель', 'год'],
#  ['апрель', 'май', 'год', 'вернуться_родина'],
#  ['гол', 'ворота'],
#  ['дать',
#   'малое',
#   'река',
#   'указать',
#   'среднегодовой',
#   'расход',
#   'различный',
#   'точка'],
#  ['дед', 'первый', 'шофер', 'россия'],
#  ['декабрь',
#   'клуб',
#   'подписать',
#   'долгосрочный',
#   'контракт',
#   'бразилец',
#   'лео',
#   'сантан'],
#  ['духовный',
#   'завѣщані',
#   'иван',
#   'лисиченка',
#   'кіевый',
#   'печерский',
#   'монастырь',
#   'свой',
#   'наслѣдственнагой',
#   'крестьянин',
#   'ѳеодора',
#   'въ',
#   'ремизовичахъ',
#   'овруч',
#   'пов'],
#  ['место',
#   'сша',
#   'популярность',
#   'коллектив',
#   'выход',
#   'диск',
#   'пойти',
#   'убыль'],
#  ['исполняться', 'частично', 'вступление'],
#  ['апрель', 'год'],
#  ['апрель', 'год'],
#  ['март', 'год'],
#  ['март', 'год'],
#  ['март', 'год', 'объявить', 'выступать', 'испанец', 'хосе', 'кальдерон'],
#  ['май', 'работать', 'кузница', 'ветряный_мельница'],
#  ['государственный', 'автомобильный', 'завод', 'имя_сталин'],
#  ['место', 'зона'],
#  ['млн',
#   'млн',
#   'электронный',
#   'медицинский',
#   'документ',
#   'подсистема',
#   'федеральный',
#   'интегрировать',
#   'электронный',
#   'медицинский',
#   'карта'],
#  ['динамика', 'рост', 'цена', 'бренд'],
#  ['причина',
#   'который',
#   'жан',
#   'баптист',
#   'леклерк',
#   'иметь',
#   'колено',
#   'балл',
#   'выступать',
#   'третий',
#   'круг',
#   'неясный'],
#  ['противотанковый', 'орудие', 'солдат_офицер', 'вермахт'],
#  ['рейтинг', 'дать', 'апрель', 'год'],
#  ['рейтинг', 'дать', 'апрель', 'год'],
#  ['рейтинг', 'дать', 'апрель', 'год'],
#  ['рейтинг', 'произойти', 'состояние', 'май', 'год'],
#  ['взрывать',
#   'любовь',
#   'тихий',
#   'дон',
#   'рукопись',
#   'роман',
#   'xx_век',
#   'водворить',
#   'госхранилище'],
#  ['сезон', 'серия', 'конец', 'серия', 'друг', 'выступать', 'твистереть'],
#  ['сентябрь', 'год', 'спустить_вода', 'сентябрь', 'год'],
#  ['сентябрь', 'северный', 'лига', 'против'],
#  ['¹слиться', 'депутат', 'либеральный_партия'],
#  ['срок', 'приближаться', 'должность', 'регламентировать', 'закон'],
#  ['июнь', 'год'],
#  ['июнь', 'год', 'запуск', 'час_минута', 'прекратить', 'апрель', 'год'],
#  ['эффект',
#   'длина',
#   'список',
#   'возможность',
#   'сериальный',
#   'вспоминание',
#   'уменьшаться',
#   'увеличение',
#   'длина',
#   'список'],
#  ['команда', 'против'],
#  ['русский', 'национальный', 'бригада', 'сс', 'год'],
#  ['лье',
#   'вода',
#   'подчеркнуть',
#   'трудность',
#   'достижение',
#   'северный',
#   'полюс'],
#  ['год', 'предоставлять', 'принцип', 'проектный', 'финансовый'],
#  ['настоящий_время', 'также', 'пригласить', 'участник', 'группа'],
#  ['также', 'сериал'],
#  ['часть', 'вообще', 'записать_студия'],
#  ['признать', 'журнал'],
#  ['вуз'],
#  ['год', 'выпуск'],
#  ['год',
#   'удостоить',
#   'международный',
#   'премия',
#   'эмми',
#   'категория',
#   'искусство'],
#  ['год', 'старый', 'сказка', 'год', 'жаль', 'ружьё'],
#  ['год',
#   'центр',
#   'анимационный',
#   'творчество',
#   'перспектива',
#   'открыть',
#   'приказ',
#   'мэр',
#   'город',
#   'ярославль',
#   'год',
#   'сразу',
#   'стать_обладатель',
#   'грант',
#   'президент_рф',
#   'область',
#   'образование',
#   'искусство'],
#  ['медоуленд', 'также', 'появиться', 'эпизод'],
#  ['испытывать', 'трудность', 'конкуренция', 'фильм_ужас', 'больший', 'бюджет'],
#  ['японский', 'суперлига', 'состав', 'токио', 'алварк'],
#  ['продать',
#   'скудный',
#   'миллион',
#   'билет',
#   'составлять',
#   'менее',
#   'половина',
#   'предоставлять',
#   'предшественник',
#   'год',
#   'назад'],
#  ['стать',
#   'крупный',
#   'бестселлер',
#   'экземпляр',
#   'тыс',
#   'израиль',
#   'он',
#   'также',
#   'снять',
#   'фильм'],
#  ['вновь', 'црвена', 'звезда', 'донецкий'],
#  ['театральный', 'фильм'],
#  ['год', 'получить'],
#  ['сыграть', 'дочь', 'мать', 'одиночка'],
#  ['prism',
#   'award',
#   'номинация',
#   'исполнение',
#   'тв',
#   'фильм',
#   'телефильм',
#   'роль',
#   'саманта',
#   'фильм'],
#  ['народный_артист', 'республика', 'адыгея'],
#  ['очередной', 'экранизация', 'роман', 'стивен', 'кинг'],
#  ['который',
#   'весьма',
#   'реакция',
#   'первый',
#   'зритель',
#   'канны',
#   'стать',
#   'культовый',
#   'итог',
#   'год',
#   'назвать',
#   'журнал'],
#  ['получить',
#   'очень',
#   'положительный_отзыв',
#   'помочь',
#   'создать',
#   'шанс',
#   'синглтон',
#   'критик'],
#  ['шрека',
#   'жить',
#   'одинокий',
#   'домик',
#   'болото',
#   'вести',
#   'монолог',
#   'жизнь',
#   'одиночка',
#   'вроде',
#   'весьма',
#   'довольный'],
#  ['снять',
#   'эндрю',
#   'лау',
#   'адам',
#   'мак',
#   'лечь_основа',
#   'оскароносный',
#   'американский',
#   'ремейк'],
#  ['также', 'главный_роль', 'сериал'],
#  ['сыграть_роль', 'сьюзен', 'боунс'],
#  ['продолжение'],
#  ['фильм'],
#  ['некоторый', 'альбом'],
#  ['друг',
#   'главный_героиня',
#   'имя',
#   'британско',
#   'французский',
#   'комедийный',
#   'фильм'],
#  ['бо_льшать', 'часть', 'представить', 'картина', 'фотография', 'продаваться'],
#  ['год', 'место', 'рейтинг', 'мировой', 'шинный', 'производитель'],
#  ['год',
#   'создатель',
#   'возникнуть',
#   'вопрос',
#   'снять',
#   'ещё_один',
#   'картина',
#   'франшиза',
#   'однако',
#   'изначально',
#   'брэд',
#   'фуллеп',
#   'эндрю',
#   'форма',
#   'хотеть',
#   'снимать',
#   'ещё',
#   'фильм'],
#  ['номинация'],
#  ['продолжить',
#   'исследование',
#   'неумолимый',
#   'рок',
#   'возможность',
#   'влиять',
#   'окружающий'],
#  ['роль', 'джордан', 'гайст'],
#  ['член', 'лига', 'справедливость'],
#  ['также', 'несколько', 'песня'],
#  ['также', 'телевизионный_фильм', 'творческий', 'объединение'],
#  ['морган', 'воплотить', 'образ', 'фелотас'],
#  ['год', 'мистер', 'фриз', 'являться', 'постоянный', 'враг', 'бэтмена'],
#  ['год',
#   'закончиться',
#   'полный',
#   'подчинение',
#   'автономия',
#   'столичный',
#   'власть'],
#  ['год',
#   'хотя',
#   'базироваться',
#   'идея',
#   'сборник',
#   'закон',
#   'роботехника',
#   'сюжетный',
#   'близкий',
#   'роман'],
#  ['достигнуть', 'значительный', 'успех', 'весь_мир'],
#  ['участие', 'третий', 'сезон', 'сериал'],
#  ['рубеж', 'спокойный', 'счастливый', 'жизнь', 'главное_герой'],
#  ['отметить',
#   'рейтинг',
#   'журнал',
#   'interview',
#   'magazine',
#   'число',
#   'шесть',
#   'актёр',
#   'который',
#   'стоить',
#   'допустить',
#   'год'],
#  ['совместно', 'группа'],
#  ['маклина',
#   'неоднократно',
#   'упоминать',
#   'интервью',
#   'работать',
#   'свой',
#   'сольный_альбом',
#   'один',
#   'песня',
#   'отец'],
#  ['отделение',
#   'монументальный',
#   'декоративный',
#   'скульптура',
#   'новосибирский',
#   'государственный',
#   'архитектура',
#   'художественный',
#   'академия'],
#  ['качество', 'эпизодический', 'персонаж'],
#  ['включить_список',
#   'сто',
#   'хороший',
#   'английский',
#   'роман',
#   'время',
#   'версия',
#   'журнал'],
#  ['год', 'предисловие', 'андрей', 'содомор'],
#  ['действие', 'который', 'происходить', 'четыре', 'доллар', 'год', 'будущее'],
#  ['вклад', 'киноискусство'],
#  ['коммерческий', 'суперхит'],
#  ['изобразить', 'слишком', 'крупный'],
#  ['производство', 'саундтрек', 'фильм'],
#  ['фильм', 'отметить', 'специальный', 'награда', 'жюри', 'золотой', 'ладья'],
#  ['который', 'принести', 'первый', 'номинация_премия'],
#  ['основатель', 'вица_президент', 'телекомпания'],
#  ['который',
#   'однако',
#   'пользоваться',
#   'президентский_выборы',
#   'поддержка',
#   'партия',
#   'грузинский',
#   'мечта',
#   'поэтому',
#   'партия',
#   'сохранить',
#   'статус',
#   'правящий'],
#  ['таксист', 'др', 'игра', 'pursuit', 'justice'],
#  ['также', 'оборотень', 'джош', 'главный_роль', 'сериал'],
#  ['также', 'роль', 'сонй', 'фильм', 'лан', 'лилля', 'вачовск'],
#  ['гармония',
#   'сквозь',
#   'хаос',
#   'путеводитель',
#   'евгений',
#   'онегин',
#   'превозмогать',
#   'тяжесть',
#   'художественный',
#   'мир',
#   'пушкин',
#   'наиболее',
#   'примечательный',
#   'произведение'],
#  ['каждый', 'который', 'роль'],
#  ['категория'],
#  ['актёр',
#   'культивировать',
#   'полюбиться',
#   'зритель',
#   'пародийный',
#   'образ',
#   'схожий',
#   'образ',
#   'дребен'],
#  ['год', 'представлять', 'белоруссия', 'конкурс'],
#  ['год',
#   'согласно',
#   'который',
#   'центральный',
#   'особенность',
#   'спорт',
#   'являться',
#   'физический',
#   'составлять',
#   'кратко',
#   'спорт',
#   'определять',
#   'турнир',
#   'различный',
#   'физический',
#   'упражнение',
#   'комплекс',
#   'также',
#   'система',
#   'организация',
#   'проведение'],
#  ['год', 'оказаться', 'менее', 'популярный'],
#  ['поздний',
#   'стать',
#   'один',
#   'первый',
#   'дабстеп',
#   'композиция',
#   'вместе',
#   'работа',
#   'digital',
#   'mystikz',
#   'kode',
#   'также',
#   'присутствовать',
#   'саундтрек',
#   'прозвучать',
#   'фильм',
#   'номинировать',
#   'кинопремия'],
#  ['один', 'многий', 'планета', 'покорить', 'криллитан'],
#  ['однако', 'также', 'несколько', 'помогать', 'продолжать', 'бороться'],
#  ['сюжет', 'шекспир', 'трагедия'],
#  ...]

# %% [markdown]
# Построим модель lda, выделим с ее помощью 15 тем.

# %%
import gensim

import gensim.corpora as corpora


dict_articles = corpora.Dictionary(list_preprocessed)
corpus = [dict_articles.doc2bow(article) for article in list_preprocessed]
lda = gensim.models.ldamodel.LdaModel(corpus=corpus, id2word=dict_articles, num_topics=15, 
                                      update_every=1, chunksize=100, passes=10, per_word_topics=True)

# %%
lda.print_topics()
# Out:
# [(0,
#   '0.128*"свой" + 0.101*"состав" + 0.092*"чемпионат" + 0.084*"выпустить" + 0.059*"два" + 0.040*"украина" + 0.029*"дебютировать" + 0.013*"заявить" + 0.013*"победить" + 0.012*"победа"'),
#  (1,
#   '0.145*"компания" + 0.090*"место" + 0.065*"журнал" + 0.037*"российский" + 0.032*"лейбл" + 0.030*"собственный" + 0.026*"приобрести" + 0.024*"крупный" + 0.023*"тот" + 0.022*"другой"'),
#  (2,
#   '0.091*"страна" + 0.087*"впервые" + 0.073*"последний" + 0.065*"игрок" + 0.047*"территория" + 0.036*"смочь" + 0.019*"полный" + 0.014*"юг" + 0.012*"пытаться" + 0.009*"север"'),
#  (3,
#   '0.037*"область" + 0.037*"район" + 0.037*"житель" + 0.030*"составлять" + 0.029*"часть" + 0.029*"право" + 0.026*"региональный" + 0.024*"уровень" + 0.024*"больший" + 0.024*"северный"'),
#  (4,
#   '0.155*"клуб" + 0.072*"работа" + 0.049*"её" + 0.036*"национальный" + 0.032*"сыграть" + 0.027*"имя" + 0.025*"записать" + 0.023*"история" + 0.022*"возглавить" + 0.022*"начало"'),
#  (5,
#   '0.069*"центр" + 0.061*"предприятие" + 0.040*"село" + 0.037*"завод" + 0.031*"городской" + 0.029*"московский" + 0.028*"преобразовать" + 0.026*"образование" + 0.025*"построить" + 0.024*"администрация"'),
#  (6,
#   '0.679*"год" + 0.024*"перейти" + 0.024*"команда" + 0.024*"группа" + 0.013*"вернуться" + 0.012*"вновь" + 0.010*"чемпионат_мир" + 0.010*"являться" + 0.008*"песня" + 0.007*"сборная"'),
#  (7,
#   '0.178*"выступать" + 0.107*"создать" + 0.063*"турнир" + 0.062*"второй" + 0.060*"человек" + 0.033*"международный" + 0.025*"дом" + 0.024*"возраст" + 0.023*"банк" + 0.020*"ребёнок"'),
#  (8,
#   '0.200*"новый" + 0.049*"управление" + 0.031*"контракт" + 0.029*"установить" + 0.029*"затем" + 0.023*"подписать" + 0.023*"художник" + 0.020*"срок" + 0.020*"материал" + 0.015*"произведение"'),
#  (9,
#   '0.095*"университет" + 0.091*"число" + 0.046*"партия" + 0.045*"совет" + 0.041*"президент" + 0.038*"член" + 0.035*"немецкий" + 0.027*"комитет" + 0.024*"подготовка" + 0.016*"учёный"'),
#  (10,
#   '0.065*"город" + 0.062*"один" + 0.055*"проект" + 0.053*"выиграть" + 0.048*"здание" + 0.035*"академия" + 0.034*"открыть" + 0.032*"результат" + 0.031*"правительство" + 0.029*"музей"'),
#  (11,
#   '0.148*"выйти" + 0.132*"получить" + 0.076*"мир" + 0.048*"матч" + 0.047*"награда" + 0.035*"стать_чемпион" + 0.033*"первенство" + 0.027*"золотой_медаль" + 0.023*"медаль" + 0.020*"завоевать_бронзовый"'),
#  (12,
#   '0.144*"стать" + 0.058*"россия" + 0.035*"название" + 0.032*"сша" + 0.031*"книга" + 0.022*"игра" + 0.021*"третий" + 0.020*"лига" + 0.018*"государственный" + 0.018*"издательство"'),
#  (13,
#   '0.103*"который" + 0.052*"фильм" + 0.037*"альбом" + 0.030*"сериал" + 0.029*"также" + 0.027*"сезон" + 0.026*"работать" + 0.025*"начать" + 0.023*"появиться" + 0.020*"участвовать"'),
#  (14,
#   '0.147*"первый" + 0.065*"провести" + 0.042*"окончить" + 0.040*"школа" + 0.039*"церковь" + 0.038*"время" + 0.031*"занимать" + 0.029*"институт" + 0.019*"самый" + 0.019*"женский"')]

# %% [markdown]
# Проверим модель в деле. Посмотрим, к каким темам она отнесет это предложение.

# %%
list_preprocessed[100]
# Out:
# ['октябрь', 'костромской', 'район', 'корова', 'костромской', 'порода']

# %%
lda.get_document_topics(dict_articles.doc2bow(list_preprocessed[100]))
# Out:
# [(0, 0.022226706),
#  (1, 0.022226706),
#  (2, 0.022226706),
#  (3, 0.35564786),
#  (4, 0.022226706),
#  (5, 0.022226706),
#  (6, 0.35540497),
#  (7, 0.022226706),
#  (8, 0.022226706),
#  (9, 0.022226706),
#  (10, 0.022226706),
#  (11, 0.022226706),
#  (12, 0.022226706),
#  (13, 0.022226706),
#  (14, 0.022226706)]

# %%
print(lda.show_topics(15)[3])
print(lda.show_topics(15)[6])
# Out:
# (3, '0.037*"область" + 0.037*"район" + 0.037*"житель" + 0.030*"составлять" + 0.029*"часть" + 0.029*"право" + 0.026*"региональный" + 0.024*"уровень" + 0.024*"больший" + 0.024*"северный"')
# (6, '0.679*"год" + 0.024*"перейти" + 0.024*"команда" + 0.024*"группа" + 0.013*"вернуться" + 0.012*"вновь" + 0.010*"чемпионат_мир" + 0.010*"являться" + 0.008*"песня" + 0.007*"сборная"')

# %% [markdown]
# Заспарсим пару страниц яндекс новостей, и проверим на них.

# %%
# !pip install requests
# !pip install bs4
# !pip install fake_useragent

import requests

from fake_useragent import UserAgent

from bs4 import BeautifulSoup as bs


url = 'https://yandex.ru/news'
response = requests.get(url, headers={'User-Agent': UserAgent().chrome})
soup = bs(response.text, 'html')

descriptions = soup.find_all('div', {'class': 'mg-card__text'})
links = [description.a.get('href') for description in descriptions]
texts = []
for i in range(3):
    import time
    
    
    time.sleep(3)  
    
    link = links[i]
    response = requests.get(link)
    soup = bs(response.text, 'html')
    lines = soup.find_all('div', {'class': 'mg-snippet__content'})
    text = ''
    for line in lines:
        try:
            texts.append(line.div.span.text)
        except:
            texts.append(line.div.text)
# Out:
# Requirement already satisfied: requests in /home/mitya/37env/lib/python3.7/site-packages (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/mitya/37env/lib/python3.7/site-packages (from requests) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/mitya/37env/lib/python3.7/site-packages (from requests) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /home/mitya/37env/lib/python3.7/site-packages (from requests) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mitya/37env/lib/python3.7/site-packages (from requests) (2021.10.8)
# Requirement already satisfied: bs4 in /home/mitya/37env/lib/python3.7/site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /home/mitya/37env/lib/python3.7/site-packages (from bs4) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in /home/mitya/37env/lib/python3.7/site-packages (from beautifulsoup4->bs4) (2.3.1)
# Requirement already satisfied: fake_useragent in /home/mitya/37env/lib/python3.7/site-packages (0.1.11)

# %%
texts_preprocessed = []
for text in (texts):
    line = simple_preprocess(text)
    l = []
    for word in line:
        if word not in stop_words:
            try:
                norm = morph.parse(word)[0].normal_form
                l.append(norm)
            except:
                l.append(word)
    texts_preprocessed.append(l)
    
texts_nicely_done = list(bigram[texts_preprocessed])
for i in range(len(texts_nicely_done)):
    for j in range(len(texts_nicely_done[i])):
        word = texts_nicely_done[i][j]
        if replace_dict.get(word, None) != None:
            texts_nicely_done[i][j] = replace_dict.get(word)

# %%
texts[0]
# Out:
# ' Группа депутатов от «Единой России» внесла в нижнюю палату парламента законопроект, который определяет условия и механизм введения внешней администрации на российских подразделениях иностранных компаний, покинувших Россию. Предполагается, что решение о введении внешнего управления будет приниматься межведомственной комиссией при Минэкономразвития. Переход управления от иностранных собственников к внешнему управлению будет назначаться только по решению суда. Иностранным собственникам сохранят возможность возобновить работу в России или продать пакет акций. В\xa0Госдуму внесли законопроект об управлении имуществом ушедших компаний Внесен законопроект о\xa0внешнем управлении иностранными компаниями, которые объявили об уходе с\xa0российского рынка В\xa0Госдуму внесли законопроект о\xa0внешнем управлении иностранным бизнесом Единая Россия внесла в\xa0Госдуму законопроект о\xa0внешнем управлении иностранными компаниями, которые объявили об уходе с\xa0российского рынка ЕР внесла в\xa0Госдуму законопроект о\xa0внешнем управлении ушедшими из\xa0России компаниями В\xa0Госдуму внесён проект о\xa0внешнем управлении объявивших об уходе иностранных компаний Законопроект о\xa0внешнем управлении компаний с\xa0«недружественным» участием сменил содержание'

# %%
lda.get_document_topics(dict_articles.doc2bow(texts_nicely_done[0]))
# Out:
# [(1, 0.2517039),
#  (3, 0.026609164),
#  (4, 0.051665258),
#  (5, 0.02666249),
#  (6, 0.05164736),
#  (8, 0.2517225),
#  (9, 0.026663115),
#  (10, 0.05166066),
#  (12, 0.15167378),
#  (13, 0.10165819)]

# %%
print(lda.show_topics(15)[1])
print(lda.show_topics(15)[8])
print(lda.show_topics(15)[12])
print(lda.show_topics(15)[13])
# Out:
# (1, '0.145*"компания" + 0.090*"место" + 0.065*"журнал" + 0.037*"российский" + 0.032*"лейбл" + 0.030*"собственный" + 0.026*"приобрести" + 0.024*"крупный" + 0.023*"тот" + 0.022*"другой"')
# (8, '0.200*"новый" + 0.049*"управление" + 0.031*"контракт" + 0.029*"установить" + 0.029*"затем" + 0.023*"подписать" + 0.023*"художник" + 0.020*"срок" + 0.020*"материал" + 0.015*"произведение"')
# (12, '0.144*"стать" + 0.058*"россия" + 0.035*"название" + 0.032*"сша" + 0.031*"книга" + 0.022*"игра" + 0.021*"третий" + 0.020*"лига" + 0.018*"государственный" + 0.018*"издательство"')
# (13, '0.103*"который" + 0.052*"фильм" + 0.037*"альбом" + 0.030*"сериал" + 0.029*"также" + 0.027*"сезон" + 0.026*"работать" + 0.025*"начать" + 0.023*"появиться" + 0.020*"участвовать"')
